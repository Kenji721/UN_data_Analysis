# %%
import pandas as pd
import re
import difflib
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("un_country_data_raw.csv")
df.head()
# Out:
#        Country             Category                      Indicator  Year  \
# 0  Afghanistan  General Information                         Region   NaN
# 1  Afghanistan  General Information         Population (000, 2024)   NaN
# 2  Afghanistan  General Information   Pop. density (per km2, 2024)   NaN
# 3  Afghanistan  General Information                   Capital city   NaN
# 4  Afghanistan  General Information  Capital city pop. (000, 2024)   NaN
#
#            Value
# 0  Southern Asia
# 1        42 648a
# 2          65.7a
# 3          Kabul
# 4       4 114.0c

# %%
df.head(50)
# Out:
#         Country             Category  \
# 0   Afghanistan  General Information
# 1   Afghanistan  General Information
# 2   Afghanistan  General Information
# 3   Afghanistan  General Information
# 4   Afghanistan  General Information
# 5   Afghanistan  General Information
# 6   Afghanistan  General Information
# 7   Afghanistan  General Information
# 8   Afghanistan  General Information
# 9   Afghanistan  General Information
# 10  Afghanistan  Economic indicators
# 11  Afghanistan  Economic indicators
# 12  Afghanistan  Economic indicators
# 13  Afghanistan  Economic indicators
# 14  Afghanistan  Economic indicators
# 15  Afghanistan  Economic indicators
# 16  Afghanistan  Economic indicators
# 17  Afghanistan  Economic indicators
# 18  Afghanistan  Economic indicators
# 19  Afghanistan  Economic indicators
# 20  Afghanistan  Economic indicators
# 21  Afghanistan  Economic indicators
# 22  Afghanistan  Economic indicators
# 23  Afghanistan  Economic indicators
# 24  Afghanistan  Economic indicators
# 25  Afghanistan  Economic indicators
# 26  Afghanistan  Economic indicators
# 27  Afghanistan  Economic indicators
# 28  Afghanistan  Economic indicators
# 29  Afghanistan  Economic indicators
# 30  Afghanistan  Economic indicators
# 31  Afghanistan  Economic indicators
# 32  Afghanistan  Economic indicators
# 33  Afghanistan  Economic indicators
# 34  Afghanistan  Economic indicators
# 35  Afghanistan  Economic indicators
# 36  Afghanistan  Economic indicators
# 37  Afghanistan  Economic indicators
# 38  Afghanistan  Economic indicators
# 39  Afghanistan  Economic indicators
# 40  Afghanistan  Economic indicators
# 41  Afghanistan  Economic indicators
# 42  Afghanistan  Economic indicators
# 43  Afghanistan  Economic indicators
# 44  Afghanistan  Economic indicators
# 45  Afghanistan  Economic indicators
# 46  Afghanistan  Economic indicators
# 47  Afghanistan  Economic indicators
# 48  Afghanistan  Economic indicators
# 49  Afghanistan  Economic indicators
#
#                                             Indicator    Year  \
# 0                                              Region     NaN
# 1                              Population (000, 2024)     NaN
# 2                        Pop. density (per km2, 2024)     NaN
# 3                                        Capital city     NaN
# 4                       Capital city pop. (000, 2024)     NaN
# 5                                  UN membership date     NaN
# 6                                  Surface area (km2)     NaN
# 7                             Sex ratio (m per 100 f)     NaN
# 8                                   National currency     NaN
# 9                             Exchange rate (per US$)     NaN
# 10  GDP: Gross domestic product (million current US$)  2015.0
# 11  GDP: Gross domestic product (million current US$)  2020.0
# 12  GDP: Gross domestic product (million current US$)  2024.0
# 13     GDP growth rate (annual %, const. 2015 prices)  2015.0
# 14     GDP growth rate (annual %, const. 2015 prices)  2020.0
# 15     GDP growth rate (annual %, const. 2015 prices)  2024.0
# 16                       GDP per capita (current US$)  2015.0
# 17                       GDP per capita (current US$)  2020.0
# 18                       GDP per capita (current US$)  2024.0
# 19     Economy: Agriculturee (% of Gross Value Added)  2015.0
# 20     Economy: Agriculturee (% of Gross Value Added)  2020.0
# 21     Economy: Agriculturee (% of Gross Value Added)  2024.0
# 22        Economy: Industrye (% of Gross Value Added)  2015.0
# 23        Economy: Industrye (% of Gross Value Added)  2020.0
# 24        Economy: Industrye (% of Gross Value Added)  2024.0
# 25   Economy: Services and other activitye (% of GVA)  2015.0
# 26   Economy: Services and other activitye (% of GVA)  2020.0
# 27   Economy: Services and other activitye (% of GVA)  2024.0
# 28         Employment in agriculturei (% of employed)  2015.0
# 29         Employment in agriculturei (% of employed)  2020.0
# 30         Employment in agriculturei (% of employed)  2024.0
# 31            Employment in industryi (% of employed)  2015.0
# 32            Employment in industryi (% of employed)  2020.0
# 33            Employment in industryi (% of employed)  2024.0
# 34               Employment in servicesi (% employed)  2015.0
# 35               Employment in servicesi (% employed)  2020.0
# 36               Employment in servicesi (% employed)  2024.0
# 37                   Unemployment (% of labour force)  2015.0
# 38                   Unemployment (% of labour force)  2020.0
# 39                   Unemployment (% of labour force)  2024.0
# 40  Labour force participation rate (female/male p...  2015.0
# 41  Labour force participation rate (female/male p...  2020.0
# 42  Labour force participation rate (female/male p...  2024.0
# 43               CPI: Consumer Price Index (2010=100)  2015.0
# 44               CPI: Consumer Price Index (2010=100)  2020.0
# 45               CPI: Consumer Price Index (2010=100)  2024.0
# 46      Agricultural production index (2014-2016=100)  2015.0
# 47      Agricultural production index (2014-2016=100)  2020.0
# 48      Agricultural production index (2014-2016=100)  2024.0
# 49  International trade: exports (million current ...  2015.0
#
#                Value
# 0      Southern Asia
# 1            42 648a
# 2              65.7a
# 3              Kabul
# 4           4 114.0c
# 5   19 November 1946
# 6           652 864b
# 7               102a
# 8      Afghani (AFN)
# 9              77.1d
# 10            18 700
# 11            19 983
# 12           14 175b
# 13              -2.5
# 14              -2.1
# 15             -6.2b
# 16               554
# 17             512.7
# 18            344.6b
# 19                22
# 20             31.4f
# 21           35.5f,b
# 22               9.6
# 23             13.6g
# 24           16.9g,b
# 25              68.3
# 26               55h
# 27           47.5h,b
# 28              44.6
# 29                46
# 30             46.6b
# 31              20.7
# 32              18.5
# 33             18.3b
# 34              34.7
# 35              35.5
# 36             35.1b
# 37                9i
# 38              11.7
# 39             16.3i
# 40      19.1 / 75.3i
# 41       16.5 / 66.7
# 42       5.0 / 69.3i
# 43               133
# 44              150c
# 45               ...
# 46                96
# 47               112
# 48              111b
# 49               571

# %%
len(df['Country'].unique())
# Out:
# 232

# %% [markdown]
# ## Split the data set by Categories

# %%
df_general_info = df[df["Category"]=="General Information"]
df_economic_indicators = df[df["Category"]=="Economic indicators"]
df_social_indicators = df[df["Category"]=="Social indicators"]
df_env_infra_indicators = df[df["Category"]=="Environment and infrastructure indicators"]
print(len(df_general_info['Country'].unique()))
print(len(df_general_info['Country'].unique()))
print(len(df_general_info['Country'].unique()))
print(len(df_general_info['Country'].unique()))
# Out:
# 232
# 232
# 232
# 232

# %%
df_general_info = df_general_info.drop(columns=["Category","Year"],axis=1)
df_general_info.head()
# Out:
#        Country                      Indicator          Value
# 0  Afghanistan                         Region  Southern Asia
# 1  Afghanistan         Population (000, 2024)        42 648a
# 2  Afghanistan   Pop. density (per km2, 2024)          65.7a
# 3  Afghanistan                   Capital city          Kabul
# 4  Afghanistan  Capital city pop. (000, 2024)       4 114.0c

# %%
def pivot_df(df,idx_cols):
    pivot_df = df.pivot(index=idx_cols, columns="Indicator",values="Value")
    flat_df = pivot_df.reset_index()
    flat_df.columns.name = None
    return flat_df

# %%
def clean_numerical_cols(df, numerical_cols):
    df_cleaned = df.copy()

    for col in numerical_cols:
        if col in df_cleaned.columns:
            df_cleaned[col] = df_cleaned[col].str.replace(r'[^\d.]', '', regex=True)
            df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce')
        else:
            print(f"Warning: Column '{col}' not found in DataFrame. Skipping.")
            
    return df_cleaned

# %% [markdown]
# ## General Information

# %%
df_general_info_flat = pivot_df(df_general_info, idx_cols=["Country"])
df_general_info_flat.head()
# Out:
#           Country      Capital city Capital city pop. (000)  \
# 0     Afghanistan             Kabul                     NaN
# 1         Albania            Tirana                     NaN
# 2         Algeria           Algiers                     NaN
# 3  American Samoa         Pago Pago                     NaN
# 4         Andorra  Andorra la Vella                     NaN
#
#   Capital city pop. (000, 2024) Exchange rate (per US$)     National currency  \
# 0                      4 114.0c                   77.1d         Afghani (AFN)
# 1                        484.6c                   93.9d             Lek (ALL)
# 2                    2 729.3c,d                  134.3e  Algerian Dinar (DZD)
# 3                         48.5d                     NaN       US Dollar (USD)
# 4                         22.6c                    0.9d            Euro (EUR)
#
#   Pop. density (per km2, 2024) Population (000, 2024)           Region  \
# 0                        65.7a                42 648a    Southern Asia
# 1                       101.9a                 2 792a  Southern Europe
# 2                        19.7a                46 814a  Northern Africa
# 3                     233.8a,b                  47a,b        Polynesia
# 4                       174.3a                    82a  Southern Europe
#
#   Sex ratio (m per 100 f) Surface area (km2) UN membership date
# 0                    102a           652 864b   19 November 1946
# 1                   97.8a            28 748b   14 December 1955
# 2                  104.1a         2 381 741b    08 October 1962
# 3                101.9a,b               199c                NaN
# 4                  104.6a               468b       28 July 1993

# %% [markdown]
# ### Note
#
# 3 Countries has Capital city pop. (000). Assming thy do not have the updated 2024 data
#
# Maybe we can just merge with Capital city pop. (000, 2024)

# %%
df_general_info_flat[df_general_info_flat["Capital city pop. (000)"].notna()]["Country"]
# Out:
# 111                    Kiribati
# 154    Northern Mariana Islands
# 212    Turks and Caicos Islands
# Name: Country, dtype: object

# %%
numerical_cols = ["Capital city pop. (000)","Capital city pop. (000, 2024)","Exchange rate (per US$)","Pop. density (per km2, 2024)","Population (000, 2024)","Sex ratio (m per 100 f)","Surface area (km2)"]
df_general_info_flat = clean_numerical_cols(df_general_info_flat,numerical_cols)
df_general_info_flat["UN membership date"] = pd.to_datetime(df_general_info_flat["UN membership date"], errors="coerce")

# %%
df_general_info_flat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        232 non-null    object
#  1   Capital city                   232 non-null    object
#  2   Capital city pop. (000)        3 non-null      float64
#  3   Capital city pop. (000, 2024)  228 non-null    float64
#  4   Exchange rate (per US$)        216 non-null    float64
#  5   National currency              231 non-null    object
#  6   Pop. density (per km2, 2024)   230 non-null    float64
#  7   Population (000, 2024)         230 non-null    float64
#  8   Region                         232 non-null    object
#  9   Sex ratio (m per 100 f)        230 non-null    float64
#  10  Surface area (km2)             226 non-null    float64
#  11  UN membership date             193 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), object(4)
# memory usage: 21.9+ KB

# %%
df_general_info_flat.head()
# Out:
#           Country      Capital city  Capital city pop. (000)  \
# 0     Afghanistan             Kabul                      NaN
# 1         Albania            Tirana                      NaN
# 2         Algeria           Algiers                      NaN
# 3  American Samoa         Pago Pago                      NaN
# 4         Andorra  Andorra la Vella                      NaN
#
#    Capital city pop. (000, 2024)  Exchange rate (per US$)  \
# 0                         4114.0                     77.1
# 1                          484.6                     93.9
# 2                         2729.3                    134.3
# 3                           48.5                      NaN
# 4                           22.6                      0.9
#
#       National currency  Pop. density (per km2, 2024)  Population (000, 2024)  \
# 0         Afghani (AFN)                          65.7                 42648.0
# 1             Lek (ALL)                         101.9                  2792.0
# 2  Algerian Dinar (DZD)                          19.7                 46814.0
# 3       US Dollar (USD)                         233.8                    47.0
# 4            Euro (EUR)                         174.3                    82.0
#
#             Region  Sex ratio (m per 100 f)  Surface area (km2)  \
# 0    Southern Asia                    102.0            652864.0
# 1  Southern Europe                     97.8             28748.0
# 2  Northern Africa                    104.1           2381741.0
# 3        Polynesia                    101.9               199.0
# 4  Southern Europe                    104.6               468.0
#
#   UN membership date
# 0         1946-11-19
# 1         1955-12-14
# 2         1962-10-08
# 3                NaT
# 4         1993-07-28

# %% [markdown]
# ### Note
#
# Some missing values. Dropping might be the solution? Further analysis on the nulls are needed

# %%
df_general_info_flat.isnull().sum()
# Out:
# Country                            0
# Capital city                       0
# Capital city pop. (000)          229
# Capital city pop. (000, 2024)      4
# Exchange rate (per US$)           16
# National currency                  1
# Pop. density (per km2, 2024)       2
# Population (000, 2024)             2
# Region                             0
# Sex ratio (m per 100 f)            2
# Surface area (km2)                 6
# UN membership date                39
# dtype: int64

# %% [markdown]
# ## Economic Indicators

# %%
df_economic_indicators = df_economic_indicators.drop(columns=["Category"],axis=1)
df_economic_indicators.head()
# Out:
#         Country                                          Indicator    Year  \
# 10  Afghanistan  GDP: Gross domestic product (million current US$)  2015.0
# 11  Afghanistan  GDP: Gross domestic product (million current US$)  2020.0
# 12  Afghanistan  GDP: Gross domestic product (million current US$)  2024.0
# 13  Afghanistan     GDP growth rate (annual %, const. 2015 prices)  2015.0
# 14  Afghanistan     GDP growth rate (annual %, const. 2015 prices)  2020.0
#
#       Value
# 10   18 700
# 11   19 983
# 12  14 175b
# 13     -2.5
# 14     -2.1

# %%
df_economic_indicators_flat = pivot_df(df_economic_indicators, idx_cols=["Country","Year"])
df_economic_indicators_flat.head()
# Out:
#        Country    Year Agricultural production index (2014-2016=100)  \
# 0  Afghanistan  2015.0                                            96
# 1  Afghanistan  2020.0                                           112
# 2  Afghanistan  2024.0                                          111b
# 3      Albania  2015.0                                           100
# 4      Albania  2020.0                                           106
#
#   Agricultural production indexa (2014-2016=100)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Balance of payments, current account (million US$)  \
# 0                                            - 4 193
# 1                                            - 3 137
# 2                                                ...
# 3                                               -980
# 4                                            - 1 315
#
#   Balance of payments, current accounta (million US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CPI: Consumer Price Index (2010=100) CPI: Consumer Price Indexe (2010=100)  \
# 0                                  133                                   NaN
# 1                                 150c                                   NaN
# 2                                  ...                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
#
#   CPI: Consumer Price Indexe,n (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexf (2010=100)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   CPI: Consumer Price Indexf,g (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexg (2010=100)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   CPI: Consumer Price Indexg,h (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexh (2010=100) CPI: Consumer Price Indexi (2010=100)  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#   CPI: Consumer Price Indexi,j (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexj (2010=100)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   111
# 4                                   121
#
#   CPI: Consumer Price Indexj,k (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexk (2010=100)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   CPI: Consumer Price Indexk,l (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexl (2010=100)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   CPI: Consumer Price Indexl,m (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexm (2010=100)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   CPI: Consumer Price Indexm,n (2010=100)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   CPI: Consumer Price Indexn (2010=100)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Economy: Agriculture (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Agricultured (% of Gross Value Added)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Economy: Agricultured,e (% of Gross Value Added)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Agriculturee (% of Gross Value Added)  \
# 0                                             22
# 1                                          31.4f
# 2                                        35.5f,b
# 3                                            NaN
# 4                                            NaN
#
#   Economy: Agriculturee,f (% of Gross Value Added)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                             22.5
# 4                                             21.9
#
#   Economy: Agriculturee,f,g (% of Gross Value Added)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Agriculturee,g,h (% of Gross Value Added)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Agriculturef (% of Gross Value Added)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Economy: Agriculturef,g (% of Gross Value Added)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Agriculturef,g,h (% of Gross Value Added)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Agricultureg (% of Gross Value Added)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Economy: Agricultureg,h (% of Gross Value Added)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Agricultureg,h,i (% of Gross Value Added)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Agricultureh,i (% of Gross Value Added)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Agricultureh,i,j (% of Gross Value Added)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Industry (% of Gross Value Added)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Economy: Industryd (% of Gross Value Added)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Economy: Industryd,f (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industrye (% of Gross Value Added)  \
# 0                                         9.6
# 1                                       13.6g
# 2                                     16.9g,b
# 3                                         NaN
# 4                                         NaN
#
#   Economy: Industrye,f (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industrye,g (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industrye,g,i (% of Gross Value Added)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Industrye,h (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industryf (% of Gross Value Added)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Economy: Industryf,g (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                          24.8
# 4                                          22.9
#
#   Economy: Industryf,g,h (% of Gross Value Added)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Industryf,g,i (% of Gross Value Added)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Industryf,h (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industryg (% of Gross Value Added)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Economy: Industryg,h (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industryg,h,i (% of Gross Value Added)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Industryg,i (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industryg,i,j (% of Gross Value Added)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Industryg,j (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industryh (% of Gross Value Added)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Economy: Industryh,i (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industryh,i,j (% of Gross Value Added)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Industryh,i,k (% of Gross Value Added)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Industryh,j (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Industryi,j (% of Gross Value Added)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Economy: Services and other activity (% of GVA)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Economy: Services and other activityd (% of GVA)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Services and other activityd,g (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activitye (% of GVA)  \
# 0                                             68.3
# 1                                              55h
# 2                                          47.5h,b
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Services and other activitye,f (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activitye,f,g (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activitye,f,i (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activitye,g (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activitye,g,j (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activitye,h (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityf (% of GVA)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Services and other activityf,g (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityf,g,i (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityf,g,j (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityf,h (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               52.7
# 4                                               55.1
#
#   Economy: Services and other activityf,i (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityg (% of GVA)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Services and other activityg,h (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityg,i (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityg,j (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityg,k (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityh (% of GVA)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Services and other activityh,i,l (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityh,j (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityh,k (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityi (% of GVA)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Services and other activityi,j (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityi,k (% of GVA)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Economy: Services and other activityj (% of GVA)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Economy: Services and other activityk (% of GVA)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Employment in agriculture (% of employed)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Employment in agriculturea,k (% of employed)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Employment in agricultured (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agriculturee (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agriculturef (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agricultureg (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agricultureh (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agriculturei (% of employed)  \
# 0                                       44.6
# 1                                         46
# 2                                      46.6b
# 3                                       41.3
# 4                                       36.2
#
#   Employment in agriculturej (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agriculturek (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agriculturel (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in agriculturem (% of employed)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Employment in industry (% of employed)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Employment in industrya,k (% of employed)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Employment in industryd (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industrye (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industryf (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industryg (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industryh (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industryi (% of employed)  \
# 0                                    20.7
# 1                                    18.5
# 2                                   18.3b
# 3                                    18.7
# 4                                    20.6
#
#   Employment in industryj (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industryk (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industryl (% of employed)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Employment in industrym (% of employed) Employment in services (% employed)  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   Employment in servicesa,k (% employed) Employment in servicesd (% employed)  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
#
#   Employment in servicese (% employed) Employment in servicesf (% employed)  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   Employment in servicesg (% employed) Employment in servicesh (% employed)  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   Employment in servicesi (% employed) Employment in servicesj (% employed)  \
# 0                                 34.7                                  NaN
# 1                                 35.5                                  NaN
# 2                                35.1b                                  NaN
# 3                                   40                                  NaN
# 4                                 43.2                                  NaN
#
#   Employment in servicesk (% employed) Employment in servicesl (% employed)  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   Employment in servicesm (% employed)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   GDP growth rate (annual %, const. 2015 prices)  \
# 0                                           -2.5
# 1                                           -2.1
# 2                                          -6.2b
# 3                                            2.2
# 4                                           -3.5
#
#   GDP growth ratea (annual %, const. 2015 prices)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   GDP growth ratee (annual %, const. 2015 prices)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   GDP growth ratef (annual %, const. 2015 prices)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   GDP per capita (current US$) GDP per capitaa (current US$)  \
# 0                          554                           NaN
# 1                        512.7                           NaN
# 2                       344.6b                           NaN
# 3                      3 950.4                           NaN
# 4                      5 289.0                           NaN
#
#   GDP per capitad (current US$) GDP per capitae (current US$)  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   GDP per capitaf (current US$)  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   GDP: Gross domestic product (million current US$)  \
# 0                                            18 700
# 1                                            19 983
# 2                                           14 175b
# 3                                            11 387
# 4                                            15 163
#
#   GDP: Gross domestic producta (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   GDP: Gross domestic productd (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   GDP: Gross domestic producte (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   GDP: Gross domestic productf (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balance (million current US$)  \
# 0                                            - 7 151
# 1                                           - 7 484i
# 2                                         - 4 337i,j
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balancea (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balanced (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balancee (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balancef (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balanceg (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balanceh (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balancei (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balancej (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balancek (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            - 2 391
# 4                                            - 2 995
#
#   International trade: balancel (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balancen (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: balanceo (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exports (million current US$)  \
# 0                                                571
# 1                                               783i
# 2                                             456i,j
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsa (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsd (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportse (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsf (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsg (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsh (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsi (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsj (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsk (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              1 930
# 4                                              2 416
#
#   International trade: exportsl (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportsn (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: exportso (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: imports (million current US$)  \
# 0                                              7 723
# 1                                             8 266i
# 2                                           4 793i,j
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsa (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsd (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importse (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsf (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsg (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsh (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsi (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsj (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsk (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              4 320
# 4                                              5 411
#
#   International trade: importsl (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importsn (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   International trade: importso (million current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation rate (female/male pop. %)  \
# 0                                       19.1 / 75.3i
# 1                                        16.5 / 66.7
# 2                                        5.0 / 69.3i
# 3                                        47.0 / 64.1
# 4                                       50.1 / 64.7i
#
#   Labour force participation ratea,k (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation rated (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation ratee (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation ratef (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation rateg (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation rateh (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation ratei (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation ratej (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation ratek (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation ratem (female/male pop. %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unemployment (% of labour force) Unemploymenta,k (% of labour force)  \
# 0                               9i                                 NaN
# 1                             11.7                                 NaN
# 2                            16.3i                                 NaN
# 3                             17.2                                 NaN
# 4                            12.8i                                 NaN
#
#   Unemploymentd (% of labour force) Unemploymente (% of labour force)  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   Unemploymentf (% of labour force) Unemploymentg (% of labour force)  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   Unemploymenth (% of labour force) Unemploymenti (% of labour force)  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   Unemploymentj (% of labour force) Unemploymentk (% of labour force)
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN

# %%
def smart_combine_typo_columns(df,root_forms):
    """
    Merge typo columns into their root forms using similarity matching
    """
    df_fixed = df.copy()
    
    # For each root form, find and merge similar columns
    for root_col in root_forms:
        if root_col in df_fixed.columns:
            similar_columns = []
            
            # Check all columns for similarity to this root form
            for col in df_fixed.columns:
                if col != root_col and col not in root_forms:  # Don't compare with itself or other root forms
                    similarity = difflib.SequenceMatcher(None, root_col.lower(), col.lower()).ratio()
                    
                    if similarity > 0.8:  # High similarity threshold
                        similar_columns.append((col, similarity))
            
            # Merge similar columns into the root column
            if similar_columns:
                print(f"\nMerging into '{root_col}':")
                print(f"  Found {len(similar_columns)} similar columns")
                
                for similar_col, sim_score in similar_columns:
                    print(f"  Merging: '{similar_col}' -> '{root_col}' (similarity: {sim_score:.3f})")
                    # Fill missing values in root column with values from similar column
                    df_fixed[root_col] = df_fixed[root_col].fillna(df_fixed[similar_col])
                    # Drop the similar column
                    df_fixed = df_fixed.drop(columns=[similar_col])
    
    return df_fixed

# %%
print(list(df_economic_indicators_flat.columns))
# Out:
# ['Country', 'Year', 'Agricultural production index (2014-2016=100)', 'Agricultural production indexa (2014-2016=100)', 'Balance of payments, current account (million US$)', 'Balance of payments, current accounta (million US$)', 'CPI: Consumer Price Index (2010=100)', 'CPI: Consumer Price Indexe (2010=100)', 'CPI: Consumer Price Indexe,n (2010=100)', 'CPI: Consumer Price Indexf (2010=100)', 'CPI: Consumer Price Indexf,g (2010=100)', 'CPI: Consumer Price Indexg (2010=100)', 'CPI: Consumer Price Indexg,h (2010=100)', 'CPI: Consumer Price Indexh (2010=100)', 'CPI: Consumer Price Indexi (2010=100)', 'CPI: Consumer Price Indexi,j (2010=100)', 'CPI: Consumer Price Indexj (2010=100)', 'CPI: Consumer Price Indexj,k (2010=100)', 'CPI: Consumer Price Indexk (2010=100)', 'CPI: Consumer Price Indexk,l (2010=100)', 'CPI: Consumer Price Indexl (2010=100)', 'CPI: Consumer Price Indexl,m (2010=100)', 'CPI: Consumer Price Indexm (2010=100)', 'CPI: Consumer Price Indexm,n (2010=100)', 'CPI: Consumer Price Indexn (2010=100)', 'Economy: Agriculture (% of Gross Value Added)', 'Economy: Agricultured (% of Gross Value Added)', 'Economy: Agricultured,e (% of Gross Value Added)', 'Economy: Agriculturee (% of Gross Value Added)', 'Economy: Agriculturee,f (% of Gross Value Added)', 'Economy: Agriculturee,f,g (% of Gross Value Added)', 'Economy: Agriculturee,g,h (% of Gross Value Added)', 'Economy: Agriculturef (% of Gross Value Added)', 'Economy: Agriculturef,g (% of Gross Value Added)', 'Economy: Agriculturef,g,h (% of Gross Value Added)', 'Economy: Agricultureg (% of Gross Value Added)', 'Economy: Agricultureg,h (% of Gross Value Added)', 'Economy: Agricultureg,h,i (% of Gross Value Added)', 'Economy: Agricultureh,i (% of Gross Value Added)', 'Economy: Agricultureh,i,j (% of Gross Value Added)', 'Economy: Industry (% of Gross Value Added)', 'Economy: Industryd (% of Gross Value Added)', 'Economy: Industryd,f (% of Gross Value Added)', 'Economy: Industrye (% of Gross Value Added)', 'Economy: Industrye,f (% of Gross Value Added)', 'Economy: Industrye,g (% of Gross Value Added)', 'Economy: Industrye,g,i (% of Gross Value Added)', 'Economy: Industrye,h (% of Gross Value Added)', 'Economy: Industryf (% of Gross Value Added)', 'Economy: Industryf,g (% of Gross Value Added)', 'Economy: Industryf,g,h (% of Gross Value Added)', 'Economy: Industryf,g,i (% of Gross Value Added)', 'Economy: Industryf,h (% of Gross Value Added)', 'Economy: Industryg (% of Gross Value Added)', 'Economy: Industryg,h (% of Gross Value Added)', 'Economy: Industryg,h,i (% of Gross Value Added)', 'Economy: Industryg,i (% of Gross Value Added)', 'Economy: Industryg,i,j (% of Gross Value Added)', 'Economy: Industryg,j (% of Gross Value Added)', 'Economy: Industryh (% of Gross Value Added)', 'Economy: Industryh,i (% of Gross Value Added)', 'Economy: Industryh,i,j (% of Gross Value Added)', 'Economy: Industryh,i,k (% of Gross Value Added)', 'Economy: Industryh,j (% of Gross Value Added)', 'Economy: Industryi,j (% of Gross Value Added)', 'Economy: Services and other activity (% of GVA)', 'Economy: Services and other activityd (% of GVA)', 'Economy: Services and other activityd,g (% of GVA)', 'Economy: Services and other activitye (% of GVA)', 'Economy: Services and other activitye,f (% of GVA)', 'Economy: Services and other activitye,f,g (% of GVA)', 'Economy: Services and other activitye,f,i (% of GVA)', 'Economy: Services and other activitye,g (% of GVA)', 'Economy: Services and other activitye,g,j (% of GVA)', 'Economy: Services and other activitye,h (% of GVA)', 'Economy: Services and other activityf (% of GVA)', 'Economy: Services and other activityf,g (% of GVA)', 'Economy: Services and other activityf,g,i (% of GVA)', 'Economy: Services and other activityf,g,j (% of GVA)', 'Economy: Services and other activityf,h (% of GVA)', 'Economy: Services and other activityf,i (% of GVA)', 'Economy: Services and other activityg (% of GVA)', 'Economy: Services and other activityg,h (% of GVA)', 'E ...

# %%
['Country', 'Year', 'Agricultural production index (2014-2016=100)', 'Agricultural production indexa (2014-2016=100)', 'Balance of payments, current account (million US$)', 'Balance of payments, current accounta (million US$)', 'CPI: Consumer Price Index (2010=100)', 'CPI: Consumer Price Indexe (2010=100)', 'CPI: Consumer Price Indexe,n (2010=100)', 'CPI: Consumer Price Indexf (2010=100)', 'CPI: Consumer Price Indexf,g (2010=100)', 'CPI: Consumer Price Indexg (2010=100)', 'CPI: Consumer Price Indexg,h (2010=100)', 'CPI: Consumer Price Indexh (2010=100)', 'CPI: Consumer Price Indexi (2010=100)', 'CPI: Consumer Price Indexi,j (2010=100)', 'CPI: Consumer Price Indexj (2010=100)', 'CPI: Consumer Price Indexj,k (2010=100)', 'CPI: Consumer Price Indexk (2010=100)', 'CPI: Consumer Price Indexk,l (2010=100)', 'CPI: Consumer Price Indexl (2010=100)', 'CPI: Consumer Price Indexl,m (2010=100)', 'CPI: Consumer Price Indexm (2010=100)', 'CPI: Consumer Price Indexm,n (2010=100)', 'CPI: Consumer Price Indexn (2010=100)', 'Economy: Agriculture (% of Gross Value Added)', 'Economy: Agricultured (% of Gross Value Added)', 'Economy: Agricultured,e (% of Gross Value Added)', 'Economy: Agriculturee (% of Gross Value Added)', 'Economy: Agriculturee,f (% of Gross Value Added)', 'Economy: Agriculturee,f,g (% of Gross Value Added)', 'Economy: Agriculturee,g,h (% of Gross Value Added)', 'Economy: Agriculturef (% of Gross Value Added)', 'Economy: Agriculturef,g (% of Gross Value Added)', 'Economy: Agriculturef,g,h (% of Gross Value Added)', 'Economy: Agricultureg (% of Gross Value Added)', 'Economy: Agricultureg,h (% of Gross Value Added)', 'Economy: Agricultureg,h,i (% of Gross Value Added)', 'Economy: Agricultureh,i (% of Gross Value Added)', 'Economy: Agricultureh,i,j (% of Gross Value Added)', 'Economy: Industry (% of Gross Value Added)', 'Economy: Industryd (% of Gross Value Added)', 'Economy: Industryd,f (% of Gross Value Added)', 'Economy: Industrye (% of Gross Value Added)', 'Economy: Industrye,f (% of Gross Value Added)', 'Economy: Industrye,g (% of Gross Value Added)', 'Economy: Industrye,g,i (% of Gross Value Added)', 'Economy: Industrye,h (% of Gross Value Added)', 'Economy: Industryf (% of Gross Value Added)', 'Economy: Industryf,g (% of Gross Value Added)', 'Economy: Industryf,g,h (% of Gross Value Added)', 'Economy: Industryf,g,i (% of Gross Value Added)', 'Economy: Industryf,h (% of Gross Value Added)', 'Economy: Industryg (% of Gross Value Added)', 'Economy: Industryg,h (% of Gross Value Added)', 'Economy: Industryg,h,i (% of Gross Value Added)', 'Economy: Industryg,i (% of Gross Value Added)', 'Economy: Industryg,i,j (% of Gross Value Added)', 'Economy: Industryg,j (% of Gross Value Added)', 'Economy: Industryh (% of Gross Value Added)', 'Economy: Industryh,i (% of Gross Value Added)', 'Economy: Industryh,i,j (% of Gross Value Added)', 'Economy: Industryh,i,k (% of Gross Value Added)', 'Economy: Industryh,j (% of Gross Value Added)', 'Economy: Industryi,j (% of Gross Value Added)', 'Economy: Services and other activity (% of GVA)', 'Economy: Services and other activityd (% of GVA)', 'Economy: Services and other activityd,g (% of GVA)', 'Economy: Services and other activitye (% of GVA)', 'Economy: Services and other activitye,f (% of GVA)', 'Economy: Services and other activitye,f,g (% of GVA)', 'Economy: Services and other activitye,f,i (% of GVA)', 'Economy: Services and other activitye,g (% of GVA)', 'Economy: Services and other activitye,g,j (% of GVA)', 'Economy: Services and other activitye,h (% of GVA)', 'Economy: Services and other activityf (% of GVA)', 'Economy: Services and other activityf,g (% of GVA)', 'Economy: Services and other activityf,g,i (% of GVA)', 'Economy: Services and other activityf,g,j (% of GVA)', 'Economy: Services and other activityf,h (% of GVA)', 'Economy: Services and other activityf,i (% of GVA)', 'Economy: Services and other activityg (% of GVA)', 'Economy: Services and other activityg,h (% of GVA)', 'Economy: Services and other activityg,i (% of GVA)', 'Economy: Services and other activityg,j (% of GVA)', 'Economy: Services and other activityg,k (% of GVA)', 'Economy: Services and other activityh (% of GVA)', 'Economy: Services and other activityh,i,l (% of GVA)', 'Economy: Services and other activityh,j (% of GVA)', 'Economy: Services and other activityh,k (% of GVA)', 'Economy: Services and other activityi (% of GVA)', 'Economy: Services and other activityi,j (% of GVA)', 'Economy: Services and other activityi,k (% of GVA)', 'Economy: Services and other activityj (% of GVA)', 'Economy: Services and other activityk (% of GVA)', 'Employment in agriculture (% of employed)', 'Employment in agriculturea,k (% of employed)', 'Employment in agricultured (% of employed)', 'Employment in agriculturee (% of employed)', 'Employment in agriculturef (% of employed)', 'Employment in agricultureg (% of employed)', 'Employment in agricultureh (% of employed)', 'Employment in agriculturei (% of employed)', 'Employment in agriculturej (% of employed)', 'Employment in agriculturek (% of employed)', 'Employment in agriculturel (% of employed)', 'Employment in agriculturem (% of employed)', 'Employment in industry (% of employed)', 'Employment in industrya,k (% of employed)', 'Employment in industryd (% of employed)', 'Employment in industrye (% of employed)', 'Employment in industryf (% of employed)', 'Employment in industryg (% of employed)', 'Employment in industryh (% of employed)', 'Employment in industryi (% of employed)', 'Employment in industryj (% of employed)', 'Employment in industryk (% of employed)', 'Employment in industryl (% of employed)', 'Employment in industrym (% of employed)', 'Employment in services (% employed)', 'Employment in servicesa,k (% employed)', 'Employment in servicesd (% employed)', 'Employment in servicese (% employed)', 'Employment in servicesf (% employed)', 'Employment in servicesg (% employed)', 'Employment in servicesh (% employed)', 'Employment in servicesi (% employed)', 'Employment in servicesj (% employed)', 'Employment in servicesk (% employed)', 'Employment in servicesl (% employed)', 'Employment in servicesm (% employed)', 'GDP growth rate (annual %, const. 2015 prices)', 'GDP growth ratea (annual %, const. 2015 prices)', 'GDP growth ratee (annual %, const. 2015 prices)', 'GDP growth ratef (annual %, const. 2015 prices)', 'GDP per capita (current US$)', 'GDP per capitaa (current US$)', 'GDP per capitad (current US$)', 'GDP per capitae (current US$)', 'GDP per capitaf (current US$)', 'GDP: Gross domestic product (million current US$)', 'GDP: Gross domestic producta (million current US$)', 'GDP: Gross domestic productd (million current US$)', 'GDP: Gross domestic producte (million current US$)', 'GDP: Gross domestic productf (million current US$)', 'International trade: balance (million current US$)', 'International trade: balancea (million current US$)', 'International trade: balanced (million current US$)', 'International trade: balancee (million current US$)', 'International trade: balancef (million current US$)', 'International trade: balanceg (million current US$)', 'International trade: balanceh (million current US$)', 'International trade: balancei (million current US$)', 'International trade: balancej (million current US$)', 'International trade: balancek (million current US$)', 'International trade: balancel (million current US$)', 'International trade: balancen (million current US$)', 'International trade: balanceo (million current US$)', 'International trade: exports (million current US$)', 'International trade: exportsa (million current US$)', 'International trade: exportsd (million current US$)', 'International trade: exportse (million current US$)', 'International trade: exportsf (million current US$)', 'International trade: exportsg (million current US$)', 'International trade: exportsh (million current US$)', 'International trade: exportsi (million current US$)', 'International trade: exportsj (million current US$)', 'International trade: exportsk (million current US$)', 'International trade: exportsl (million current US$)', 'International trade: exportsn (million current US$)', 'International trade: exportso (million current US$)', 'International trade: imports (million current US$)', 'International trade: importsa (million current US$)', 'International trade: importsd (million current US$)', 'International trade: importse (million current US$)', 'International trade: importsf (million current US$)', 'International trade: importsg (million current US$)', 'International trade: importsh (million current US$)', 'International trade: importsi (million current US$)', 'International trade: importsj (million current US$)', 'International trade: importsk (million current US$)', 'International trade: importsl (million current US$)', 'International trade: importsn (million current US$)', 'International trade: importso (million current US$)', 'Labour force participation rate (female/male pop. %)', 'Labour force participation ratea,k (female/male pop. %)', 'Labour force participation rated (female/male pop. %)', 'Labour force participation ratee (female/male pop. %)', 'Labour force participation ratef (female/male pop. %)', 'Labour force participation rateg (female/male pop. %)', 'Labour force participation rateh (female/male pop. %)', 'Labour force participation ratei (female/male pop. %)', 'Labour force participation ratej (female/male pop. %)', 'Labour force participation ratek (female/male pop. %)', 'Labour force participation ratem (female/male pop. %)', 'Unemployment (% of labour force)', 'Unemploymenta,k (% of labour force)', 'Unemploymentd (% of labour force)', 'Unemploymente (% of labour force)', 'Unemploymentf (% of labour force)', 'Unemploymentg (% of labour force)', 'Unemploymenth (% of labour force)', 'Unemploymenti (% of labour force)', 'Unemploymentj (% of labour force)', 'Unemploymentk (% of labour force)']
# Out:
# ['Country',
#  'Year',
#  'Agricultural production index (2014-2016=100)',
#  'Agricultural production indexa (2014-2016=100)',
#  'Balance of payments, current account (million US$)',
#  'Balance of payments, current accounta (million US$)',
#  'CPI: Consumer Price Index (2010=100)',
#  'CPI: Consumer Price Indexe (2010=100)',
#  'CPI: Consumer Price Indexe,n (2010=100)',
#  'CPI: Consumer Price Indexf (2010=100)',
#  'CPI: Consumer Price Indexf,g (2010=100)',
#  'CPI: Consumer Price Indexg (2010=100)',
#  'CPI: Consumer Price Indexg,h (2010=100)',
#  'CPI: Consumer Price Indexh (2010=100)',
#  'CPI: Consumer Price Indexi (2010=100)',
#  'CPI: Consumer Price Indexi,j (2010=100)',
#  'CPI: Consumer Price Indexj (2010=100)',
#  'CPI: Consumer Price Indexj,k (2010=100)',
#  'CPI: Consumer Price Indexk (2010=100)',
#  'CPI: Consumer Price Indexk,l (2010=100)',
#  'CPI: Consumer Price Indexl (2010=100)',
#  'CPI: Consumer Price Indexl,m (2010=100)',
#  'CPI: Consumer Price Indexm (2010=100)',
#  'CPI: Consumer Price Indexm,n (2010=100)',
#  'CPI: Consumer Price Indexn (2010=100)',
#  'Economy: Agriculture (% of Gross Value Added)',
#  'Economy: Agricultured (% of Gross Value Added)',
#  'Economy: Agricultured,e (% of Gross Value Added)',
#  'Economy: Agriculturee (% of Gross Value Added)',
#  'Economy: Agriculturee,f (% of Gross Value Added)',
#  'Economy: Agriculturee,f,g (% of Gross Value Added)',
#  'Economy: Agriculturee,g,h (% of Gross Value Added)',
#  'Economy: Agriculturef (% of Gross Value Added)',
#  'Economy: Agriculturef,g (% of Gross Value Added)',
#  'Economy: Agriculturef,g,h (% of Gross Value Added)',
#  'Economy: Agricultureg (% of Gross Value Added)',
#  'Economy: Agricultureg,h (% of Gross Value Added)',
#  'Economy: Agricultureg,h,i (% of Gross Value Added)',
#  'Economy: Agricultureh,i (% of Gross Value Added)',
#  'Economy: Agricultureh,i,j (% of Gross Value Added)',
#  'Economy: Industry (% of Gross Value Added)',
#  'Economy: Industryd (% of Gross Value Added)',
#  'Economy: Industryd,f (% of Gross Value Added)',
#  'Economy: Industrye (% of Gross Value Added)',
#  'Economy: Industrye,f (% of Gross Value Added)',
#  'Economy: Industrye,g (% of Gross Value Added)',
#  'Economy: Industrye,g,i (% of Gross Value Added)',
#  'Economy: Industrye,h (% of Gross Value Added)',
#  'Economy: Industryf (% of Gross Value Added)',
#  'Economy: Industryf,g (% of Gross Value Added)',
#  'Economy: Industryf,g,h (% of Gross Value Added)',
#  'Economy: Industryf,g,i (% of Gross Value Added)',
#  'Economy: Industryf,h (% of Gross Value Added)',
#  'Economy: Industryg (% of Gross Value Added)',
#  'Economy: Industryg,h (% of Gross Value Added)',
#  'Economy: Industryg,h,i (% of Gross Value Added)',
#  'Economy: Industryg,i (% of Gross Value Added)',
#  'Economy: Industryg,i,j (% of Gross Value Added)',
#  'Economy: Industryg,j (% of Gross Value Added)',
#  'Economy: Industryh (% of Gross Value Added)',
#  'Economy: Industryh,i (% of Gross Value Added)',
#  'Economy: Industryh,i,j (% of Gross Value Added)',
#  'Economy: Industryh,i,k (% of Gross Value Added)',
#  'Economy: Industryh,j (% of Gross Value Added)',
#  'Economy: Industryi,j (% of Gross Value Added)',
#  'Economy: Services and other activity (% of GVA)',
#  'Economy: Services and other activityd (% of GVA)',
#  'Economy: Services and other activityd,g (% of GVA)',
#  'Economy: Services and other activitye (% of GVA)',
#  'Economy: Services and other activitye,f (% of GVA)',
#  'Economy: Services and other activitye,f,g (% of GVA)',
#  'Economy: Services and other activitye,f,i (% of GVA)',
#  'Economy: Services and other activitye,g (% of GVA)',
#  'Economy: Services and other activitye,g,j (% of GVA)',
#  'Economy: Services and other activitye,h (% of GVA)',
#  'Economy: Services and other activityf (% of GVA)',
#  'Economy: Services and other activityf,g (% of GVA)',
#  'Economy: Services and other activityf,g,i (% of GVA)',
#  'Economy: Services and other activityf,g,j (% of GVA)',
#  'Economy: Services and other activityf,h (% of GVA)',
#  'Economy: Services and other activityf,i (% of GVA)',
#  'Economy: Services and other activityg (% of GVA)',
#  'Economy: Services and other activityg,h (% of GVA)',
#  'Economy: Services and other activityg,i (% of GVA)',
#  'Economy: Services and other activityg,j (% of GVA)',
#  'Economy: Services and other activityg,k (% of GVA)',
#  'Economy: Services and other activityh (% of GVA)',
#  'Economy: Services and other activityh,i,l (% of GVA)',
#  'Economy: Services and other activityh,j (% of GVA)',
#  'Economy: Services and other activityh,k (% of GVA)',
#  'Economy: Services and other activityi (% of GVA)',
#  'Economy: Services and other activityi,j (% of GVA)',
#  'Economy: Services and other activityi,k (% of GVA)',
#  'Economy: Services and other activityj (% of GVA)',
#  'Economy: Services and other activityk (% of GVA)',
#  'Employment in agriculture (% of employed)',
#  'Employment in agriculturea,k (% of employed)',
#  'Employment in agricultured (% of employed)',
#  'Employment in agriculturee (% of employed)',
#  'Employment in agriculturef (% of employed)',
#  'Employment in agricultureg (% of employed)',
#  'Employment in agricultureh (% of employed)',
#  'Employment in agriculturei (% of employed)',
#  'Employment in agriculturej (% of employed)',
#  'Employment in agriculturek (% of employed)',
#  'Employment in agriculturel (% of employed)',
#  'Employment in agriculturem (% of employed)',
#  'Employment in industry (% of employed)',
#  'Employment in industrya,k (% of employed)',
#  'Employment in industryd (% of employed)',
#  'Employment in industrye (% of employed)',
#  'Employment in industryf (% of employed)',
#  'Employment in industryg (% of employed)',
#  'Employment in industryh (% of employed)',
#  'Employment in industryi (% of employed)',
#  'Employment in industryj (% of employed)',
#  'Employment in industryk (% of employed)',
#  'Employment in industryl (% of employed)',
#  'Employment in industrym (% of employed)',
#  'Employment in services (% employed)',
#  'Employment in servicesa,k (% employed)',
#  'Employment in servicesd (% employed)',
#  'Employment in servicese (% employed)',
#  'Employment in servicesf (% employed)',
#  'Employment in servicesg (% employed)',
#  'Employment in servicesh (% employed)',
#  'Employment in servicesi (% employed)',
#  'Employment in servicesj (% employed)',
#  'Employment in servicesk (% employed)',
#  'Employment in servicesl (% employed)',
#  'Employment in servicesm (% employed)',
#  'GDP growth rate (annual %, const. 2015 prices)',
#  'GDP growth ratea (annual %, const. 2015 prices)',
#  'GDP growth ratee (annual %, const. 2015 prices)',
#  'GDP growth ratef (annual %, const. 2015 prices)',
#  'GDP per capita (current US$)',
#  'GDP per capitaa (current US$)',
#  'GDP per capitad (current US$)',
#  'GDP per capitae (current US$)',
#  'GDP per capitaf (current US$)',
#  'GDP: Gross domestic product (million current US$)',
#  'GDP: Gross domestic producta (million current US$)',
#  'GDP: Gross domestic productd (million current US$)',
#  'GDP: Gross domestic producte (million current US$)',
#  'GDP: Gross domestic productf (million current US$)',
#  'International trade: balance (million current US$)',
#  'International trade: balancea (million current US$)',
#  'International trade: balanced (million current US$)',
#  'International trade: balancee (million current US$)',
#  'International trade: balancef (million current US$)',
#  'International trade: balanceg (million current US$)',
#  'International trade: balanceh (million current US$)',
#  'International trade: balancei (million current US$)',
#  'International trade: balancej (million current US$)',
#  'International trade: balancek (million current US$)',
#  'International trade: balancel (million current US$)',
#  'International trade: balancen (million current US$)',
#  'International trade: balanceo (million current US$)',
#  'International trade: exports (million current US$)',
#  'International trade: exportsa (million current US$)',
#  'International trade: exportsd (million current US$)',
#  'International trade: exportse (million current US$)',
#  'International trade: exportsf (million current US$)',
#  'International trade: exportsg (million current US$)',
#  'International trade: exportsh (million current US$)',
#  'International trade: exportsi (million current US$)',
#  'International trade: exportsj (million current US$)',
#  'International trade: exportsk (million current US$)',
#  'International trade: exportsl (million current US$)',
#  'International trade: exportsn (million current US$)',
#  'International trade: exportso (million current US$)',
#  'International trade: imports (million current US$)',
#  'International trade: importsa (million current US$)',
#  'International trade: importsd (million current US$)',
#  'International trade: importse (million current US$)',
#  'International trade: importsf (million current US$)',
#  'International trade: importsg (million current US$)',
#  'International trade: importsh (million current US$)',
#  'International trade: importsi (million current US$)',
#  'International trade: importsj (million current US$)',
#  'International trade: importsk (million current US$)',
#  'International trade: importsl (million current US$)',
#  'International trade: importsn (million current US$)',
#  'International trade: importso (million current US$)',
#  'Labour force participation rate (female/male pop. %)',
#  'Labour force participation ratea,k (female/male pop. %)',
#  'Labour force participation rated (female/male pop. %)',
#  'Labour force participation ratee (female/male pop. %)',
#  'Labour force participation ratef (female/male pop. %)',
#  'Labour force participation rateg (female/male pop. %)',
#  'Labour force participation rateh (female/male pop. %)',
#  'Labour force participation ratei (female/male pop. %)',
#  'Labour force participation ratej (female/male pop. %)',
#  'Labour force participation ratek (female/male pop. %)',
#  'Labour force participation ratem (female/male pop. %)',
#  'Unemployment (% of labour force)',
#  'Unemploymenta,k (% of labour force)',
#  'Unemploymentd (% of labour force)',
#  'Unemploymente (% of labour force)',
#  'Unemploymentf (% of labour force)',
#  'Unemploymentg (% of labour force)',
#  'Unemploymenth (% of labour force)',
#  'Unemploymenti (% of labour force)',
#  'Unemploymentj (% of labour force)',
#  'Unemploymentk (% of labour force)']

# %%
root_forms = [
    'Country',
    'Year',
    'Agricultural production index (2014-2016=100)',
    'Balance of payments, current account (million US$)',
    'CPI: Consumer Price Index (2010=100)',
    'Economy: Agriculture (% of Gross Value Added)',
    'Economy: Industry (% of Gross Value Added)',
    'Economy: Services and other activity (% of GVA)',
    'Employment in agriculture (% of employed)',
    'Employment in industry (% of employed)',
    'Employment in services (% employed)',
    'GDP growth rate (annual %, const. 2015 prices)',
    'GDP per capita (current US$)',
    'GDP: Gross domestic product (million current US$)',
    'International trade: balance (million current US$)',
    'International trade: exports (million current US$)',
    'International trade: imports (million current US$)',
    'Labour force participation rate (female/male pop. %)',
    'Unemployment (% of labour force)'
]

df_economic_indicators_flat = smart_combine_typo_columns(df_economic_indicators_flat, root_forms)
print(f"\nFinal shape: {df_economic_indicators_flat.shape}")
print(f"Final columns: {list(df_economic_indicators_flat.columns)}")
df_economic_indicators_flat.head()
# Out:
# Merging into 'Agricultural production index (2014-2016=100)':
#   Found 1 similar columns
#   Merging: 'Agricultural production indexa (2014-2016=100)' -> 'Agricultural production index (2014-2016=100)' (similarity: 0.989)
#
# Merging into 'Balance of payments, current account (million US$)':
#   Found 1 similar columns
#   Merging: 'Balance of payments, current accounta (million US$)' -> 'Balance of payments, current account (million US$)' (similarity: 0.990)
#
# Merging into 'CPI: Consumer Price Index (2010=100)':
#   Found 18 similar columns
#   Merging: 'CPI: Consumer Price Indexe (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexe,n (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexf (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexf,g (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexg (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexg,h (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexh (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexi (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexi,j (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexj (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexj,k (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexk (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexk,l (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexl (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexl,m (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexm (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#   Merging: 'CPI: Consumer Price Indexm,n (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.960)
#   Merging: 'CPI: Consumer Price Indexn (2010=100)' -> 'CPI: Consumer Price Index (2010=100)' (similarity: 0.986)
#
# Merging into 'Economy: Agriculture (% of Gross Value Added)':
#   Found 15 similar columns
#   Merging: 'Economy: Agricultured (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.989)
#   Merging: 'Economy: Agricultured,e (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.968)
#   Merging: 'Economy: Agriculturee (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.989)
#   Merging: 'Economy: Agriculturee,f (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.968)
#   Merging: 'Economy: Agriculturee,f,g (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.947)
#   Merging: 'Economy: Agriculturee,g,h (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.947)
#   Merging: 'Economy: Agriculturef (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.989)
#   Merging: 'Economy: Agriculturef,g (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.968)
#   Merging: 'Economy: Agriculturef,g,h (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.947)
#   Merging: 'Economy: Agricultureg (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.989)
#   Merging: 'Economy: Agricultureg,h (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.968)
#   Merging: 'Economy: Agricultureg,h,i (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.947)
#   Merging: 'Economy: Agricultureh,i (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.968)
#   Merging: 'Economy: Agricultureh,i,j (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.947)
#   Merging: 'Economy: Industrye (% of Gross Value Added)' -> 'Economy: Agriculture (% of Gross Value Added)' (similarity: 0.818)
#
# Merging into 'Economy: Industry (% of Gross Value Added)':
#   Found 23 similar columns
#   Merging: 'Economy: Industryd (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.988)
#   Merging: 'Economy: Industryd,f (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industrye,f (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industrye,g (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industrye,g,i (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.944)
#   Merging: 'Economy: Industrye,h (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryf (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.988)
#   Merging: 'Economy: Industryf,g (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryf,g,h (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.944)
#   Merging: 'Economy: Industryf,g,i (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.944)
#   Merging: 'Economy: Industryf,h (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryg (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.988)
#   Merging: 'Economy: Industryg,h (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryg,h,i (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.944)
#   Merging: 'Economy: Industryg,i (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryg,i,j (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.944)
#   Merging: 'Economy: Industryg,j (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryh (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.988)
#   Merging: 'Economy: Industryh,i (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryh,i,j (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.944)
#   Merging: 'Economy: Industryh,i,k (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.944)
#   Merging: 'Economy: Industryh,j (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#   Merging: 'Economy: Industryi,j (% of Gross Value Added)' -> 'Economy: Industry (% of Gross Value Added)' (similarity: 0.966)
#
# Merging into 'Economy: Services and other activity (% of GVA)':
#   Found 29 similar columns
#   Merging: 'Economy: Services and other activityd (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#   Merging: 'Economy: Services and other activityd,g (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activitye (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#   Merging: 'Economy: Services and other activitye,f (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activitye,f,g (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.949)
#   Merging: 'Economy: Services and other activitye,f,i (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.949)
#   Merging: 'Economy: Services and other activitye,g (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activitye,g,j (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.949)
#   Merging: 'Economy: Services and other activitye,h (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityf (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#   Merging: 'Economy: Services and other activityf,g (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityf,g,i (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.949)
#   Merging: 'Economy: Services and other activityf,g,j (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.949)
#   Merging: 'Economy: Services and other activityf,h (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityf,i (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityg (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#   Merging: 'Economy: Services and other activityg,h (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityg,i (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityg,j (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityg,k (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityh (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#   Merging: 'Economy: Services and other activityh,i,l (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.949)
#   Merging: 'Economy: Services and other activityh,j (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityh,k (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityi (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#   Merging: 'Economy: Services and other activityi,j (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityi,k (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.969)
#   Merging: 'Economy: Services and other activityj (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#   Merging: 'Economy: Services and other activityk (% of GVA)' -> 'Economy: Services and other activity (% of GVA)' (similarity: 0.989)
#
# Merging into 'Employment in agriculture (% of employed)':
#   Found 21 similar columns
#   Merging: 'Employment in agriculturea,k (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.965)
#   Merging: 'Employment in agricultured (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agriculturee (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agriculturef (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agricultureg (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agricultureh (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agriculturei (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agriculturej (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agriculturek (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agriculturel (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in agriculturem (% of employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.988)
#   Merging: 'Employment in servicesd (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicese (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesf (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesg (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesh (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesi (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesj (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesk (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesl (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#   Merging: 'Employment in servicesm (% employed)' -> 'Employment in agriculture (% of employed)' (similarity: 0.805)
#
# Merging into 'Employment in industry (% of employed)':
#   Found 11 similar columns
#   Merging: 'Employment in industrya,k (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.962)
#   Merging: 'Employment in industryd (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industrye (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industryf (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industryg (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industryh (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industryi (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industryj (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industryk (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industryl (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#   Merging: 'Employment in industrym (% of employed)' -> 'Employment in industry (% of employed)' (similarity: 0.987)
#
# Merging into 'Employment in services (% employed)':
#   Found 1 similar columns
#   Merging: 'Employment in servicesa,k (% employed)' -> 'Employment in services (% employed)' (similarity: 0.959)
#
# Merging into 'GDP growth rate (annual %, const. 2015 prices)':
#   Found 3 similar columns
#   Merging: 'GDP growth ratea (annual %, const. 2015 prices)' -> 'GDP growth rate (annual %, const. 2015 prices)' (similarity: 0.989)
#   Merging: 'GDP growth ratee (annual %, const. 2015 prices)' -> 'GDP growth rate (annual %, const. 2015 prices)' (similarity: 0.989)
#   Merging: 'GDP growth ratef (annual %, const. 2015 prices)' -> 'GDP growth rate (annual %, const. 2015 prices)' (similarity: 0.989)
#
# Merging into 'GDP per capita (current US$)':
#   Found 4 similar columns
#   Merging: 'GDP per capitaa (current US$)' -> 'GDP per capita (current US$)' (similarity: 0.982)
#   Merging: 'GDP per capitad (current US$)' -> 'GDP per capita (current US$)' (similarity: 0.982)
#   Merging: 'GDP per capitae (current US$)' -> 'GDP per capita (current US$)' (similarity: 0.982)
#   Merging: 'GDP per capitaf (current US$)' -> 'GDP per capita (current US$)' (similarity: 0.982)
#
# Merging into 'GDP: Gross domestic product (million current US$)':
#   Found 4 similar columns
#   Merging: 'GDP: Gross domestic producta (million current US$)' -> 'GDP: Gross domestic product (million current US$)' (similarity: 0.990)
#   Merging: 'GDP: Gross domestic productd (million current US$)' -> 'GDP: Gross domestic product (million current US$)' (similarity: 0.990)
#   Merging: 'GDP: Gross domestic producte (million current US$)' -> 'GDP: Gross domestic product (million current US$)' (similarity: 0.990)
#   Merging: 'GDP: Gross domestic productf (million current US$)' -> 'GDP: Gross domestic product (million current US$)' (similarity: 0.990)
#
# Merging into 'International trade: balance (million current US$)':
#   Found 36 similar columns
#   Merging: 'International trade: balancea (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balanced (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balancee (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balancef (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balanceg (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balanceh (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balancei (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balancej (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balancek (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balancel (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balancen (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: balanceo (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.990)
#   Merging: 'International trade: exportsa (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsd (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportse (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsf (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsg (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsh (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsi (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsj (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsk (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsl (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportsn (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: exportso (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: importsa (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: importsd (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#   Merging: 'International trade: importse (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: importsf (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#   Merging: 'International trade: importsg (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#   Merging: 'International trade: importsh (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#   Merging: 'International trade: importsi (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#   Merging: 'International trade: importsj (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#   Merging: 'International trade: importsk (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#   Merging: 'International trade: importsl (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: importsn (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.871)
#   Merging: 'International trade: importso (million current US$)' -> 'International trade: balance (million current US$)' (similarity: 0.851)
#
# Merging into 'Labour force participation rate (female/male pop. %)':
#   Found 10 similar columns
#   Merging: 'Labour force participation ratea,k (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.972)
#   Merging: 'Labour force participation rated (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation ratee (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation ratef (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation rateg (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation rateh (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation ratei (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation ratej (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation ratek (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#   Merging: 'Labour force participation ratem (female/male pop. %)' -> 'Labour force participation rate (female/male pop. %)' (similarity: 0.990)
#
# Merging into 'Unemployment (% of labour force)':
#   Found 9 similar columns
#   Merging: 'Unemploymenta,k (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.955)
#   Merging: 'Unemploymentd (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#   Merging: 'Unemploymente (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#   Merging: 'Unemploymentf (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#   Merging: 'Unemploymentg (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#   Merging: 'Unemploymenth (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#   Merging: 'Unemploymenti (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#   Merging: 'Unemploymentj (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#   Merging: 'Unemploymentk (% of labour force)' -> 'Unemployment (% of labour force)' (similarity: 0.985)
#
# Final shape: (687, 19)
# Final columns: ['Country', 'Year', 'Agricultural production index (2014-2016=100)', 'Balance of payments, current account (million US$)', 'CPI: Consumer Price Index (2010=100)', 'Economy: Agriculture (% of Gross Value Added)', 'Economy: Industry (% of Gross Value Added)', 'Economy: Services and other activity (% of GVA)', 'Employment in agriculture (% of employed)', 'Employment in industry (% of employed)', 'Employment in services (% employed)', 'GDP growth rate (annual %, const. 2015 prices)', 'GDP per capita (current US$)', 'GDP: Gross domestic product (million current US$)', 'International trade: balance (million current US$)', 'International trade: exports (million current US$)', 'International trade: imports (million current US$)', 'Labour force participation rate (female/male pop. %)', 'Unemployment (% of labour force)']
#        Country    Year Agricultural production index (2014-2016=100)  \
# 0  Afghanistan  2015.0                                            96
# 1  Afghanistan  2020.0                                           112
# 2  Afghanistan  2024.0                                          111b
# 3      Albania  2015.0                                           100
# 4      Albania  2020.0                                           106
#
#   Balance of payments, current account (million US$)  \
# 0                                            - 4 193
# 1                                            - 3 137
# 2                                                ...
# 3                                               -980
# 4                                            - 1 315
#
#   CPI: Consumer Price Index (2010=100)  \
# 0                                  133
# 1                                 150c
# 2                                  ...
# 3                                  111
# 4                                  121
#
#   Economy: Agriculture (% of Gross Value Added)  \
# 0                                            22
# 1                                         31.4f
# 2                                       35.5f,b
# 3                                          22.5
# 4                                          21.9
#
#   Economy: Industry (% of Gross Value Added)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                       24.8
# 4                                       22.9
#
#   Economy: Services and other activity (% of GVA)  \
# 0                                            68.3
# 1                                             55h
# 2                                         47.5h,b
# 3                                            52.7
# 4                                            55.1
#
#   Employment in agriculture (% of employed)  \
# 0                                      44.6
# 1                                        46
# 2                                     46.6b
# 3                                      41.3
# 4                                      36.2
#
#   Employment in industry (% of employed) Employment in services (% employed)  \
# 0                                   20.7                                 NaN
# 1                                   18.5                                 NaN
# 2                                  18.3b                                 NaN
# 3                                   18.7                                 NaN
# 4                                   20.6                                 NaN
#
#   GDP growth rate (annual %, const. 2015 prices) GDP per capita (current US$)  \
# 0                                           -2.5                          554
# 1                                           -2.1                        512.7
# 2                                          -6.2b                       344.6b
# 3                                            2.2                      3 950.4
# 4                                           -3.5                      5 289.0
#
#   GDP: Gross domestic product (million current US$)  \
# 0                                            18 700
# 1                                            19 983
# 2                                           14 175b
# 3                                            11 387
# 4                                            15 163
#
#   International trade: balance (million current US$)  \
# 0                                            - 7 151
# 1                                           - 7 484i
# 2                                         - 4 337i,j
# 3                                            - 2 391
# 4                                            - 2 995
#
#   International trade: exports (million current US$)  \
# 0                                                571
# 1                                               783i
# 2                                             456i,j
# 3                                                NaN
# 4                                                NaN
#
#   International trade: imports (million current US$)  \
# 0                                              7 723
# 1                                             8 266i
# 2                                           4 793i,j
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation rate (female/male pop. %)  \
# 0                                       19.1 / 75.3i
# 1                                        16.5 / 66.7
# 2                                        5.0 / 69.3i
# 3                                        47.0 / 64.1
# 4                                       50.1 / 64.7i
#
#   Unemployment (% of labour force)
# 0                               9i
# 1                             11.7
# 2                            16.3i
# 3                             17.2
# 4                            12.8i

# %%
df_economic_indicators_flat.isnull().sum()
# Out:
# Country                                                   0
# Year                                                      0
# Agricultural production index (2014-2016=100)            93
# Balance of payments, current account (million US$)      102
# CPI: Consumer Price Index (2010=100)                     72
# Economy: Agriculture (% of Gross Value Added)            66
# Economy: Industry (% of Gross Value Added)               75
# Economy: Services and other activity (% of GVA)          57
# Employment in agriculture (% of employed)                81
# Employment in industry (% of employed)                   78
# Employment in services (% employed)                     639
# GDP growth rate (annual %, const. 2015 prices)           57
# GDP per capita (current US$)                             57
# GDP: Gross domestic product (million current US$)        57
# International trade: balance (million current US$)       54
# International trade: exports (million current US$)      195
# International trade: imports (million current US$)      195
# Labour force participation rate (female/male pop. %)     75
# Unemployment (% of labour force)                         57
# dtype: int64

# %%
numerical_cols = [
    'Agricultural production index (2014-2016=100)',
    'Balance of payments, current account (million US$)',
    'CPI: Consumer Price Index (2010=100)',
    'Economy: Agriculture (% of Gross Value Added)',
    'Economy: Industry (% of Gross Value Added)',
    'Economy: Services and other activity (% of GVA)',
    'Employment in agriculture (% of employed)',
    'Employment in industry (% of employed)',
    'Employment in services (% employed)',
    'GDP growth rate (annual %, const. 2015 prices)',
    'GDP per capita (current US$)',
    'GDP: Gross domestic product (million current US$)',
    'International trade: balance (million current US$)',
    'International trade: exports (million current US$)',
    'International trade: imports (million current US$)',
    'Unemployment (% of labour force)'
]

# %%
df_economic_indicators_flat = clean_numerical_cols(df_economic_indicators_flat, numerical_cols)
df_economic_indicators_flat.head()
# Out:
#        Country    Year  Agricultural production index (2014-2016=100)  \
# 0  Afghanistan  2015.0                                           96.0
# 1  Afghanistan  2020.0                                          112.0
# 2  Afghanistan  2024.0                                          111.0
# 3      Albania  2015.0                                          100.0
# 4      Albania  2020.0                                          106.0
#
#    Balance of payments, current account (million US$)  \
# 0                                             4193.0
# 1                                             3137.0
# 2                                                NaN
# 3                                              980.0
# 4                                             1315.0
#
#    CPI: Consumer Price Index (2010=100)  \
# 0                                 133.0
# 1                                 150.0
# 2                                   NaN
# 3                                 111.0
# 4                                 121.0
#
#    Economy: Agriculture (% of Gross Value Added)  \
# 0                                           22.0
# 1                                           31.4
# 2                                           35.5
# 3                                           22.5
# 4                                           21.9
#
#    Economy: Industry (% of Gross Value Added)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                        24.8
# 4                                        22.9
#
#    Economy: Services and other activity (% of GVA)  \
# 0                                             68.3
# 1                                             55.0
# 2                                             47.5
# 3                                             52.7
# 4                                             55.1
#
#    Employment in agriculture (% of employed)  \
# 0                                       44.6
# 1                                       46.0
# 2                                       46.6
# 3                                       41.3
# 4                                       36.2
#
#    Employment in industry (% of employed)  \
# 0                                    20.7
# 1                                    18.5
# 2                                    18.3
# 3                                    18.7
# 4                                    20.6
#
#    Employment in services (% employed)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    GDP growth rate (annual %, const. 2015 prices)  \
# 0                                             2.5
# 1                                             2.1
# 2                                             6.2
# 3                                             2.2
# 4                                             3.5
#
#    GDP per capita (current US$)  \
# 0                         554.0
# 1                         512.7
# 2                         344.6
# 3                        3950.4
# 4                        5289.0
#
#    GDP: Gross domestic product (million current US$)  \
# 0                                            18700.0
# 1                                            19983.0
# 2                                            14175.0
# 3                                            11387.0
# 4                                            15163.0
#
#    International trade: balance (million current US$)  \
# 0                                             7151.0
# 1                                             7484.0
# 2                                             4337.0
# 3                                             2391.0
# 4                                             2995.0
#
#    International trade: exports (million current US$)  \
# 0                                              571.0
# 1                                              783.0
# 2                                              456.0
# 3                                                NaN
# 4                                                NaN
#
#    International trade: imports (million current US$)  \
# 0                                             7723.0
# 1                                             8266.0
# 2                                             4793.0
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation rate (female/male pop. %)  \
# 0                                       19.1 / 75.3i
# 1                                        16.5 / 66.7
# 2                                        5.0 / 69.3i
# 3                                        47.0 / 64.1
# 4                                       50.1 / 64.7i
#
#    Unemployment (% of labour force)
# 0                               9.0
# 1                              11.7
# 2                              16.3
# 3                              17.2
# 4                              12.8

# %%
def split_ratio_column(df, column_to_split, new_col1_name, new_col2_name):
    """
    Split a column with format "value1 / value2" into separate columns
    
    Parameters:
    df: DataFrame to modify
    column_to_split: Name of the column to split (should contain values like "19.1 / 75.3i")
    new_col1_name: Name for the first value column
    new_col2_name: Name for the second value column
    
    Returns:
    DataFrame with new columns added and ratio calculated
    """
    df_result = df.copy()
    
    if column_to_split in df_result.columns:
        # Split the column on '/'
        split_data = df_result[column_to_split].str.split('/', expand=True)
        
        if split_data.shape[1] >= 2:
            # Clean and convert first value
            df_result[new_col1_name] = split_data[0].str.strip().str.replace(r'[^\d.]', '', regex=True)
            df_result[new_col1_name] = pd.to_numeric(df_result[new_col1_name], errors='coerce')
            
            # Clean and convert second value
            df_result[new_col2_name] = split_data[1].str.strip().str.replace(r'[^\d.]', '', regex=True)
            df_result[new_col2_name] = pd.to_numeric(df_result[new_col2_name], errors='coerce')
            
            # Calculate ratio
            ratio_col_name = f"{new_col1_name.split(' (')[0]}/{new_col2_name.split(' (')[0]} Ratio"
            df_result[ratio_col_name] = (df_result[new_col1_name] / df_result[new_col2_name])*100
            
            print(f"Successfully split '{column_to_split}' into:")
            print(f"  - {new_col1_name}")
            print(f"  - {new_col2_name}")
            print(f"  - {ratio_col_name}")
        else:
            print(f"Warning: Could not split '{column_to_split}' - unexpected format")
    else:
        print(f"Warning: Column '{column_to_split}' not found in DataFrame")
    
    return df_result

# %%
#Split labor force partition and calculate the %
df_economic_indicators_flat = split_ratio_column(df_economic_indicators_flat,"Labour force participation rate (female/male pop. %)",female_col, male_col)
df_economic_indicators_flat.head()
# Out:
# Successfully split 'Labour force participation rate (female/male pop. %)' into:
#   - Labour force participation rate - Female (%)
#   - Labour force participation rate - Male (%)
#   - Labour force participation rate - Female/Labour force participation rate - Male Ratio
#        Country    Year  Agricultural production index (2014-2016=100)  \
# 0  Afghanistan  2015.0                                           96.0
# 1  Afghanistan  2020.0                                          112.0
# 2  Afghanistan  2024.0                                          111.0
# 3      Albania  2015.0                                          100.0
# 4      Albania  2020.0                                          106.0
#
#    Balance of payments, current account (million US$)  \
# 0                                             4193.0
# 1                                             3137.0
# 2                                                NaN
# 3                                              980.0
# 4                                             1315.0
#
#    CPI: Consumer Price Index (2010=100)  \
# 0                                 133.0
# 1                                 150.0
# 2                                   NaN
# 3                                 111.0
# 4                                 121.0
#
#    Economy: Agriculture (% of Gross Value Added)  \
# 0                                           22.0
# 1                                           31.4
# 2                                           35.5
# 3                                           22.5
# 4                                           21.9
#
#    Economy: Industry (% of Gross Value Added)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                        24.8
# 4                                        22.9
#
#    Economy: Services and other activity (% of GVA)  \
# 0                                             68.3
# 1                                             55.0
# 2                                             47.5
# 3                                             52.7
# 4                                             55.1
#
#    Employment in agriculture (% of employed)  \
# 0                                       44.6
# 1                                       46.0
# 2                                       46.6
# 3                                       41.3
# 4                                       36.2
#
#    Employment in industry (% of employed)  \
# 0                                    20.7
# 1                                    18.5
# 2                                    18.3
# 3                                    18.7
# 4                                    20.6
#
#    Employment in services (% employed)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    GDP growth rate (annual %, const. 2015 prices)  \
# 0                                             2.5
# 1                                             2.1
# 2                                             6.2
# 3                                             2.2
# 4                                             3.5
#
#    GDP per capita (current US$)  \
# 0                         554.0
# 1                         512.7
# 2                         344.6
# 3                        3950.4
# 4                        5289.0
#
#    GDP: Gross domestic product (million current US$)  \
# 0                                            18700.0
# 1                                            19983.0
# 2                                            14175.0
# 3                                            11387.0
# 4                                            15163.0
#
#    International trade: balance (million current US$)  \
# 0                                             7151.0
# 1                                             7484.0
# 2                                             4337.0
# 3                                             2391.0
# 4                                             2995.0
#
#    International trade: exports (million current US$)  \
# 0                                              571.0
# 1                                              783.0
# 2                                              456.0
# 3                                                NaN
# 4                                                NaN
#
#    International trade: imports (million current US$)  \
# 0                                             7723.0
# 1                                             8266.0
# 2                                             4793.0
# 3                                                NaN
# 4                                                NaN
#
#   Labour force participation rate (female/male pop. %)  \
# 0                                       19.1 / 75.3i
# 1                                        16.5 / 66.7
# 2                                        5.0 / 69.3i
# 3                                        47.0 / 64.1
# 4                                       50.1 / 64.7i
#
#    Unemployment (% of labour force)  \
# 0                               9.0
# 1                              11.7
# 2                              16.3
# 3                              17.2
# 4                              12.8
#
#    Labour force participation rate - Female (%)  \
# 0                                          19.1
# 1                                          16.5
# 2                                           5.0
# 3                                          47.0
# 4                                          50.1
#
#    Labour force participation rate - Male (%)  \
# 0                                        75.3
# 1                                        66.7
# 2                                        69.3
# 3                                        64.1
# 4                                        64.7
#
#    Labour force participation rate - Female/Labour force participation rate - Male Ratio
# 0                                          25.365206
# 1                                          24.737631
# 2                                           7.215007
# 3                                          73.322933
# 4                                          77.434312

# %%
df_economic_indicators_flat = df_economic_indicators_flat.drop(columns=["Labour force participation rate (female/male pop. %)"],axis=1)
df_economic_indicators_flat.head()
# Out:
#        Country    Year  Agricultural production index (2014-2016=100)  \
# 0  Afghanistan  2015.0                                           96.0
# 1  Afghanistan  2020.0                                          112.0
# 2  Afghanistan  2024.0                                          111.0
# 3      Albania  2015.0                                          100.0
# 4      Albania  2020.0                                          106.0
#
#    Balance of payments, current account (million US$)  \
# 0                                             4193.0
# 1                                             3137.0
# 2                                                NaN
# 3                                              980.0
# 4                                             1315.0
#
#    CPI: Consumer Price Index (2010=100)  \
# 0                                 133.0
# 1                                 150.0
# 2                                   NaN
# 3                                 111.0
# 4                                 121.0
#
#    Economy: Agriculture (% of Gross Value Added)  \
# 0                                           22.0
# 1                                           31.4
# 2                                           35.5
# 3                                           22.5
# 4                                           21.9
#
#    Economy: Industry (% of Gross Value Added)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                        24.8
# 4                                        22.9
#
#    Economy: Services and other activity (% of GVA)  \
# 0                                             68.3
# 1                                             55.0
# 2                                             47.5
# 3                                             52.7
# 4                                             55.1
#
#    Employment in agriculture (% of employed)  \
# 0                                       44.6
# 1                                       46.0
# 2                                       46.6
# 3                                       41.3
# 4                                       36.2
#
#    Employment in industry (% of employed)  \
# 0                                    20.7
# 1                                    18.5
# 2                                    18.3
# 3                                    18.7
# 4                                    20.6
#
#    Employment in services (% employed)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    GDP growth rate (annual %, const. 2015 prices)  \
# 0                                             2.5
# 1                                             2.1
# 2                                             6.2
# 3                                             2.2
# 4                                             3.5
#
#    GDP per capita (current US$)  \
# 0                         554.0
# 1                         512.7
# 2                         344.6
# 3                        3950.4
# 4                        5289.0
#
#    GDP: Gross domestic product (million current US$)  \
# 0                                            18700.0
# 1                                            19983.0
# 2                                            14175.0
# 3                                            11387.0
# 4                                            15163.0
#
#    International trade: balance (million current US$)  \
# 0                                             7151.0
# 1                                             7484.0
# 2                                             4337.0
# 3                                             2391.0
# 4                                             2995.0
#
#    International trade: exports (million current US$)  \
# 0                                              571.0
# 1                                              783.0
# 2                                              456.0
# 3                                                NaN
# 4                                                NaN
#
#    International trade: imports (million current US$)  \
# 0                                             7723.0
# 1                                             8266.0
# 2                                             4793.0
# 3                                                NaN
# 4                                                NaN
#
#    Unemployment (% of labour force)  \
# 0                               9.0
# 1                              11.7
# 2                              16.3
# 3                              17.2
# 4                              12.8
#
#    Labour force participation rate - Female (%)  \
# 0                                          19.1
# 1                                          16.5
# 2                                           5.0
# 3                                          47.0
# 4                                          50.1
#
#    Labour force participation rate - Male (%)  \
# 0                                        75.3
# 1                                        66.7
# 2                                        69.3
# 3                                        64.1
# 4                                        64.7
#
#    Labour force participation rate - Female/Labour force participation rate - Male Ratio
# 0                                          25.365206
# 1                                          24.737631
# 2                                           7.215007
# 3                                          73.322933
# 4                                          77.434312

# %% [markdown]
# ## Clean Social Indicators

# %%
df_social_indicators.head()
# Out:
#         Country           Category                                  Indicator  \
# 61  Afghanistan  Social indicators  Population growth rate (average annual %)
# 62  Afghanistan  Social indicators  Population growth rate (average annual %)
# 63  Afghanistan  Social indicators  Population growth rate (average annual %)
# 64  Afghanistan  Social indicators   Urban population (% of total population)
# 65  Afghanistan  Social indicators   Urban population (% of total population)
#
#       Year  Value
# 61  2015.0    2.3
# 62  2020.0    3.3
# 63  2024.0   2.8a
# 64  2015.0   24.8
# 65  2020.0  25.8c

# %%
df_social_indicators = df_social_indicators.drop(columns=["Category"],axis=1)
df_social_indicators.head()
# Out:
#         Country                                  Indicator    Year  Value
# 61  Afghanistan  Population growth rate (average annual %)  2015.0    2.3
# 62  Afghanistan  Population growth rate (average annual %)  2020.0    3.3
# 63  Afghanistan  Population growth rate (average annual %)  2024.0   2.8a
# 64  Afghanistan   Urban population (% of total population)  2015.0   24.8
# 65  Afghanistan   Urban population (% of total population)  2020.0  25.8c

# %%
df_social_indicators_flat = pivot_df(df_social_indicators, idx_cols=["Country","Year"])
df_social_indicators_flat.head()
# Out:
#        Country    Year Education: Government expenditure (% of GDP)  \
# 0  Afghanistan  2015.0                                          3.3
# 1  Afghanistan  2020.0                                          2.9
# 2  Afghanistan  2024.0                                          ...
# 3      Albania  2015.0                                          3.4
# 4      Albania  2020.0                                          3.3
#
#   Education: Government expendituref (% of GDP)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Education: Government expenditurei (% of GDP)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Education: Lowr. sec. gross enrol. ratio  (f/m per 100 pop.)  \
# 0                                        47.0 / 80.3
# 1                                       53.8 / 90.0c
# 2                                          ... / ...
# 3                                      105.5 / 108.6
# 4                                       95.4 / 101.6
#
#   Education: Lowr. sec. gross enrol. ratio f (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Lowr. sec. gross enrol. ratio g (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Lowr. sec. gross enrol. ratio i (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Lowr. sec. gross enrol. ratio j (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Lowr. sec. gross enrol. ratio k (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Lowr. sec. gross enrol. ratio l (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Lowr. sec. gross enrol. ratio o (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                       85.9 / 125.4
# 1                                      88.3 / 130.6c
# 2                                          ... / ...
# 3                                      111.5 / 115.0
# 4                                       98.0 / 103.2
#
#   Education: Primary gross enrol. ratiof (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Primary gross enrol. ratiog (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Primary gross enrol. ratioi (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Primary gross enrol. ratioj (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Primary gross enrol. ratiok (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Primary gross enrol. ratiol (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Primary gross enrol. ratioo (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)  \
# 0                                        27.9 / 54.3
# 1                                       29.3 / 54.1q
# 2                                          ... / ...
# 3                                       91.5 / 105.3
# 4                                        89.4 / 97.2
#
#   Education: Upr. Sec. gross enrol. ratiof (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Upr. Sec. gross enrol. ratiog (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Upr. Sec. gross enrol. ratioi (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Upr. Sec. gross enrol. ratioj (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Upr. Sec. gross enrol. ratiok (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Upr. Sec. gross enrol. ratiol (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Education: Upr. Sec. gross enrol. ratioo (f/m per 100 pop.)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Fertility rate, total (live births per woman)  \
# 0                                           5.7
# 1                                           5.1
# 2                                          4.8a
# 3                                           1.6
# 4                                           1.4
#
#   Fertility rate, totala (live births per woman)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Fertility rate, totalb (live births per woman)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Fertility rate, totald (live births per woman)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Fertility rate, totalk (live births per woman)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Fertility rate, totalo (live births per woman)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Health: Current expenditure (% of GDP)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    6.5
# 4                                    7.5
#
#   Health: Current expenditurec,o (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expendituree,i (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expendituree,j (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expendituref,j (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expendituref,j,k (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expendituref,m,n (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expendituref,o,p (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expendituref,s (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditureg,j (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditureg,l (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurei (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditurei,j,k (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditurei,m (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurei,o (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurei,o,p (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditurei,t,u (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditurej (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditurej,k (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurej,k,l (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditurej,o,p (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditurej,p (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurej,p,q (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditurej,q (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurej,r (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurek (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditurek,l (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurek,q (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurek,q,r (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditurel (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditurel,m (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurem (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditurem,n (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expendituren (% of GDP)  \
# 0                                    10.1
# 1                                   15.5o
# 2                                 21.8o,p
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expendituren,o (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditureo (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditureo,p (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditureo,p,q (% of GDP)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Health: Current expenditureo,q (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurep (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditurep,q (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditureq (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditureq,r (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditurer (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditurer,s (% of GDP)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Health: Current expenditures (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expendituret (% of GDP)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Health: Current expenditureu (% of GDP) Health: Physicians (per 1 000 pop.)  \
# 0                                     NaN                                 0.3
# 1                                     NaN                                 0.3
# 2                                     NaN                                 ...
# 3                                     NaN                                1.3o
# 4                                     NaN                                 1.9
#
#   Intentional homicide rate (per 100 000 pop.)  \
# 0                                           10
# 1                                          6.6
# 2                                           4p
# 3                                          2.2
# 4                                          2.1
#
#   International migrant stock (000/% of total pop.)  \
# 0                                      339.4 / 1.0m
# 1                                      144.1 / 0.4m
# 2                                         ... / ...
# 3                                        52.0 / 1.8
# 4                                        48.8 / 1.7
#
#   Life expectancy at birth (females/males, years)  \
# 0                                     64.2 / 60.4
# 1                                     64.7 / 58.5
# 2                                    67.8 / 64.7a
# 3                                     80.5 / 76.3
# 4                                     80.3 / 75.4
#
#   Life expectancy at birtha (females/males, years)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Life expectancy at birthb (females/males, years)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Life expectancy at birthd (females/males, years)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Life expectancy at birthk (females/males, years)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Life expectancy at birtho (females/males, years)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Population age distributiona,h (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,i (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,j (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,l (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,m (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,n (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,o (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,p (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,q (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiona,t (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,g (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,h (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,j (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,k (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,l (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,m (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,n (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,o (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,q (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,r (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionb,w (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiong (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionh (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributioni (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionj (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionk (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionl (0-14/60+ years old, %)  \
# 0                                         46.3 / 3.7
# 1                                         44.2 / 3.8
# 2                                        42.9 / 3.9a
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionm (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                        19.0 / 17.7
# 4                                        17.5 / 21.1
#
#   Population age distributionn (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributiono (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionp (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionq (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population age distributionr (0-14/60+ years old, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Population growth rate (average annual %)  \
# 0                                       2.3
# 1                                       3.3
# 2                                      2.8a
# 3                                      -0.2
# 4                                      -0.4
#
#   Population growth ratea (average annual %)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Population growth rateb (average annual %)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Population growth rated (average annual %)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Population growth ratek (average annual %)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Population growth rateo (average annual %)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Refugees and others of concern to UNHCR (000)  \
# 0                                       1 421.4
# 1                                       2 802.9
# 2                                      3 346.2j
# 3                                           8.1
# 4                                           3.6
#
#   Refugees and others of concern to UNHCRa (000)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Seats held by women in national parliaments (%)  \
# 0                                            27.7
# 1                                             27r
# 2                                         27r,s,b
# 3                                            20.7
# 4                                           29.5p
#
#   Seats held by women in national parliamentsr (%)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Seats held by women in national parliamentss (%)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Under five mortality rate (per 1000 live births)  \
# 0                                             76.5
# 1                                             62.9
# 2                                            54.5a
# 3                                             10.1
# 4                                              9.4
#
#   Under five mortality ratea (per 1000 live births)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Under five mortality rateb (per 1000 live births)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Under five mortality rated (per 1000 live births)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Under five mortality ratek (per 1000 live births)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Under five mortality rateo (per 1000 live births)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Urban population (% of total population)  \
# 0                                     24.8
# 1                                    25.8c
# 2                                      ...
# 3                                     57.4
# 4                                    61.2c
#
#   Urban population growth rate (average annual %)  \
# 0                                              4k
# 1                                             ...
# 2                                             ...
# 3                                            1.8l
# 4                                             ...
#
#   Urban populationa (% of total population)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Urban populationb (% of total population)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Urban populationc (% of total population)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Urban populationd (% of total population)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Urban populationf (% of total population)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Urban populationm (% of total population)
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %%
print(list(df_social_indicators_flat.columns))
# Out:
# ['Country', 'Year', 'Education: Government expenditure (% of GDP)', 'Education: Government expendituref (% of GDP)', 'Education: Government expenditurei (% of GDP)', 'Education: Lowr. sec. gross enrol. ratio  (f/m per 100 pop.)', 'Education: Lowr. sec. gross enrol. ratio f (f/m per 100 pop.)', 'Education: Lowr. sec. gross enrol. ratio g (f/m per 100 pop.)', 'Education: Lowr. sec. gross enrol. ratio i (f/m per 100 pop.)', 'Education: Lowr. sec. gross enrol. ratio j (f/m per 100 pop.)', 'Education: Lowr. sec. gross enrol. ratio k (f/m per 100 pop.)', 'Education: Lowr. sec. gross enrol. ratio l (f/m per 100 pop.)', 'Education: Lowr. sec. gross enrol. ratio o (f/m per 100 pop.)', 'Education: Primary gross enrol. ratio (f/m per 100 pop.)', 'Education: Primary gross enrol. ratiof (f/m per 100 pop.)', 'Education: Primary gross enrol. ratiog (f/m per 100 pop.)', 'Education: Primary gross enrol. ratioi (f/m per 100 pop.)', 'Education: Primary gross enrol. ratioj (f/m per 100 pop.)', 'Education: Primary gross enrol. ratiok (f/m per 100 pop.)', 'Education: Primary gross enrol. ratiol (f/m per 100 pop.)', 'Education: Primary gross enrol. ratioo (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratiof (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratiog (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratioi (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratioj (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratiok (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratiol (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratioo (f/m per 100 pop.)', 'Fertility rate, total (live births per woman)', 'Fertility rate, totala (live births per woman)', 'Fertility rate, totalb (live births per woman)', 'Fertility rate, totald (live births per woman)', 'Fertility rate, totalk (live births per woman)', 'Fertility rate, totalo (live births per woman)', 'Health: Current expenditure (% of GDP)', 'Health: Current expenditurec,o (% of GDP)', 'Health: Current expendituree,i (% of GDP)', 'Health: Current expendituree,j (% of GDP)', 'Health: Current expendituref,j (% of GDP)', 'Health: Current expendituref,j,k (% of GDP)', 'Health: Current expendituref,m,n (% of GDP)', 'Health: Current expendituref,o,p (% of GDP)', 'Health: Current expendituref,s (% of GDP)', 'Health: Current expenditureg,j (% of GDP)', 'Health: Current expenditureg,l (% of GDP)', 'Health: Current expenditurei (% of GDP)', 'Health: Current expenditurei,j,k (% of GDP)', 'Health: Current expenditurei,m (% of GDP)', 'Health: Current expenditurei,o (% of GDP)', 'Health: Current expenditurei,o,p (% of GDP)', 'Health: Current expenditurei,t,u (% of GDP)', 'Health: Current expenditurej (% of GDP)', 'Health: Current expenditurej,k (% of GDP)', 'Health: Current expenditurej,k,l (% of GDP)', 'Health: Current expenditurej,o,p (% of GDP)', 'Health: Current expenditurej,p (% of GDP)', 'Health: Current expenditurej,p,q (% of GDP)', 'Health: Current expenditurej,q (% of GDP)', 'Health: Current expenditurej,r (% of GDP)', 'Health: Current expenditurek (% of GDP)', 'Health: Current expenditurek,l (% of GDP)', 'Health: Current expenditurek,q (% of GDP)', 'Health: Current expenditurek,q,r (% of GDP)', 'Health: Current expenditurel (% of GDP)', 'Health: Current expenditurel,m (% of GDP)', 'Health: Current expenditurem (% of GDP)', 'Health: Current expenditurem,n (% of GDP)', 'Health: Current expendituren (% of GDP)', 'Health: Current expendituren,o (% of GDP)', 'Health: Current expenditureo (% of GDP)', 'Health: Current expenditureo,p (% of GDP)', 'Health: Current expenditureo,p,q (% of GDP)', 'Health: Current expenditureo,q (% of GDP)', 'Health: Current expenditurep (% of GDP)', 'Health: Current expenditurep,q (% of GDP)', 'Health: Current expenditureq (% of GDP)', 'Health: Current expenditureq,r (% of GDP)', 'Health: Current expenditurer (% of GDP)', 'Health: Current expenditurer,s (% of GDP)', 'H ...

# %%
root_column_names = [
    'Country',
    'Year',
    'Education: Government expenditure (% of GDP)',
    'Education: Lowr. sec. gross enrol. ratio (f/m per 100 pop.)',
    'Education: Primary gross enrol. ratio (f/m per 100 pop.)',
    'Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)',
    'Fertility rate, total (live births per woman)',
    'Health: Current expenditure (% of GDP)',
    'Health: Physicians (per 1 000 pop.)',
    'Intentional homicide rate (per 100 000 pop.)',
    'International migrant stock (000/% of total pop.)',
    'Life expectancy at birth (females/males, years)',
    'Population age distributiona,h (0-14/60+ years old, %)',
    'Population growth rate (average annual %)',
    'Refugees and others of concern to UNHCR (000)',
    'Seats held by women in national parliaments (%)',
    'Under five mortality rate (per 1000 live births)',
    'Urban population (% of total population)',
    'Urban population growth rate (average annual %)'
]

df_social_indicators_flat = smart_combine_typo_columns(df_social_indicators_flat, root_column_names)
print(f"\nFinal shape: {df_social_indicators_flat.shape}")
print(f"Final columns: {list(df_social_indicators_flat.columns)}")
df_social_indicators_flat.rename(columns={"Population age distributiona,h (0-14/60+ years old, %)":"Population age distribution (0-14/60+ years old, %)"},inplace=True)
df_social_indicators_flat.head()
# Out:
# Merging into 'Education: Government expenditure (% of GDP)':
#   Found 2 similar columns
#   Merging: 'Education: Government expendituref (% of GDP)' -> 'Education: Government expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Education: Government expenditurei (% of GDP)' -> 'Education: Government expenditure (% of GDP)' (similarity: 0.989)
#
# Merging into 'Education: Primary gross enrol. ratio (f/m per 100 pop.)':
#   Found 22 similar columns
#   Merging: 'Education: Lowr. sec. gross enrol. ratio  (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.862)
#   Merging: 'Education: Lowr. sec. gross enrol. ratio f (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.855)
#   Merging: 'Education: Lowr. sec. gross enrol. ratio g (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.855)
#   Merging: 'Education: Lowr. sec. gross enrol. ratio i (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.855)
#   Merging: 'Education: Lowr. sec. gross enrol. ratio j (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.855)
#   Merging: 'Education: Lowr. sec. gross enrol. ratio k (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.855)
#   Merging: 'Education: Lowr. sec. gross enrol. ratio l (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.855)
#   Merging: 'Education: Lowr. sec. gross enrol. ratio o (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.855)
#   Merging: 'Education: Primary gross enrol. ratiof (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.991)
#   Merging: 'Education: Primary gross enrol. ratiog (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.991)
#   Merging: 'Education: Primary gross enrol. ratioi (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.991)
#   Merging: 'Education: Primary gross enrol. ratioj (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.991)
#   Merging: 'Education: Primary gross enrol. ratiok (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.991)
#   Merging: 'Education: Primary gross enrol. ratiol (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.991)
#   Merging: 'Education: Primary gross enrol. ratioo (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.991)
#   Merging: 'Education: Upr. Sec. gross enrol. ratiof (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.887)
#   Merging: 'Education: Upr. Sec. gross enrol. ratiog (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.887)
#   Merging: 'Education: Upr. Sec. gross enrol. ratioi (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.887)
#   Merging: 'Education: Upr. Sec. gross enrol. ratioj (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.887)
#   Merging: 'Education: Upr. Sec. gross enrol. ratiok (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.887)
#   Merging: 'Education: Upr. Sec. gross enrol. ratiol (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.887)
#   Merging: 'Education: Upr. Sec. gross enrol. ratioo (f/m per 100 pop.)' -> 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' (similarity: 0.887)
#
# Merging into 'Fertility rate, total (live births per woman)':
#   Found 5 similar columns
#   Merging: 'Fertility rate, totala (live births per woman)' -> 'Fertility rate, total (live births per woman)' (similarity: 0.989)
#   Merging: 'Fertility rate, totalb (live births per woman)' -> 'Fertility rate, total (live births per woman)' (similarity: 0.989)
#   Merging: 'Fertility rate, totald (live births per woman)' -> 'Fertility rate, total (live births per woman)' (similarity: 0.989)
#   Merging: 'Fertility rate, totalk (live births per woman)' -> 'Fertility rate, total (live births per woman)' (similarity: 0.989)
#   Merging: 'Fertility rate, totalo (live births per woman)' -> 'Fertility rate, total (live births per woman)' (similarity: 0.989)
#
# Merging into 'Health: Current expenditure (% of GDP)':
#   Found 47 similar columns
#   Merging: 'Health: Current expenditurec,o (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expendituree,i (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expendituree,j (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expendituref,j (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expendituref,j,k (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expendituref,m,n (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expendituref,o,p (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expendituref,s (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditureg,j (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditureg,l (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurei (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditurei,j,k (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditurei,m (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurei,o (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurei,o,p (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditurei,t,u (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditurej (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditurej,k (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurej,k,l (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditurej,o,p (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditurej,p (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurej,p,q (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditurej,q (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurej,r (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurek (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditurek,l (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurek,q (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurek,q,r (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditurel (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditurel,m (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurem (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditurem,n (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expendituren (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expendituren,o (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditureo (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditureo,p (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditureo,p,q (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.938)
#   Merging: 'Health: Current expenditureo,q (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurep (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditurep,q (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditureq (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditureq,r (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditurer (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditurer,s (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.962)
#   Merging: 'Health: Current expenditures (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expendituret (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#   Merging: 'Health: Current expenditureu (% of GDP)' -> 'Health: Current expenditure (% of GDP)' (similarity: 0.987)
#
# Merging into 'Life expectancy at birth (females/males, years)':
#   Found 5 similar columns
#   Merging: 'Life expectancy at birtha (females/males, years)' -> 'Life expectancy at birth (females/males, years)' (similarity: 0.989)
#   Merging: 'Life expectancy at birthb (females/males, years)' -> 'Life expectancy at birth (females/males, years)' (similarity: 0.989)
#   Merging: 'Life expectancy at birthd (females/males, years)' -> 'Life expectancy at birth (females/males, years)' (similarity: 0.989)
#   Merging: 'Life expectancy at birthk (females/males, years)' -> 'Life expectancy at birth (females/males, years)' (similarity: 0.989)
#   Merging: 'Life expectancy at birtho (females/males, years)' -> 'Life expectancy at birth (females/males, years)' (similarity: 0.989)
#
# Merging into 'Population age distributiona,h (0-14/60+ years old, %)':
#   Found 32 similar columns
#   Merging: 'Population age distributiona,i (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,j (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,l (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,m (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,n (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,o (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,p (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,q (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributiona,t (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributionb,g (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,h (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributionb,j (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,k (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,l (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,m (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,n (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,o (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,q (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,r (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributionb,w (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.963)
#   Merging: 'Population age distributiong (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionh (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.981)
#   Merging: 'Population age distributioni (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionj (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionk (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionl (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionm (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionn (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributiono (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionp (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionq (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#   Merging: 'Population age distributionr (0-14/60+ years old, %)' -> 'Population age distributiona,h (0-14/60+ years old, %)' (similarity: 0.962)
#
# Merging into 'Population growth rate (average annual %)':
#   Found 5 similar columns
#   Merging: 'Population growth ratea (average annual %)' -> 'Population growth rate (average annual %)' (similarity: 0.988)
#   Merging: 'Population growth rateb (average annual %)' -> 'Population growth rate (average annual %)' (similarity: 0.988)
#   Merging: 'Population growth rated (average annual %)' -> 'Population growth rate (average annual %)' (similarity: 0.988)
#   Merging: 'Population growth ratek (average annual %)' -> 'Population growth rate (average annual %)' (similarity: 0.988)
#   Merging: 'Population growth rateo (average annual %)' -> 'Population growth rate (average annual %)' (similarity: 0.988)
#
# Merging into 'Refugees and others of concern to UNHCR (000)':
#   Found 1 similar columns
#   Merging: 'Refugees and others of concern to UNHCRa (000)' -> 'Refugees and others of concern to UNHCR (000)' (similarity: 0.989)
#
# Merging into 'Seats held by women in national parliaments (%)':
#   Found 2 similar columns
#   Merging: 'Seats held by women in national parliamentsr (%)' -> 'Seats held by women in national parliaments (%)' (similarity: 0.989)
#   Merging: 'Seats held by women in national parliamentss (%)' -> 'Seats held by women in national parliaments (%)' (similarity: 0.989)
#
# Merging into 'Under five mortality rate (per 1000 live births)':
#   Found 5 similar columns
#   Merging: 'Under five mortality ratea (per 1000 live births)' -> 'Under five mortality rate (per 1000 live births)' (similarity: 0.990)
#   Merging: 'Under five mortality rateb (per 1000 live births)' -> 'Under five mortality rate (per 1000 live births)' (similarity: 0.990)
#   Merging: 'Under five mortality rated (per 1000 live births)' -> 'Under five mortality rate (per 1000 live births)' (similarity: 0.990)
#   Merging: 'Under five mortality ratek (per 1000 live births)' -> 'Under five mortality rate (per 1000 live births)' (similarity: 0.990)
#   Merging: 'Under five mortality rateo (per 1000 live births)' -> 'Under five mortality rate (per 1000 live births)' (similarity: 0.990)
#
# Merging into 'Urban population (% of total population)':
#   Found 6 similar columns
#   Merging: 'Urban populationa (% of total population)' -> 'Urban population (% of total population)' (similarity: 0.988)
#   Merging: 'Urban populationb (% of total population)' -> 'Urban population (% of total population)' (similarity: 0.988)
#   Merging: 'Urban populationc (% of total population)' -> 'Urban population (% of total population)' (similarity: 0.988)
#   Merging: 'Urban populationd (% of total population)' -> 'Urban population (% of total population)' (similarity: 0.988)
#   Merging: 'Urban populationf (% of total population)' -> 'Urban population (% of total population)' (similarity: 0.988)
#   Merging: 'Urban populationm (% of total population)' -> 'Urban population (% of total population)' (similarity: 0.988)
#
# Final shape: (696, 18)
# Final columns: ['Country', 'Year', 'Education: Government expenditure (% of GDP)', 'Education: Primary gross enrol. ratio (f/m per 100 pop.)', 'Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)', 'Fertility rate, total (live births per woman)', 'Health: Current expenditure (% of GDP)', 'Health: Physicians (per 1 000 pop.)', 'Intentional homicide rate (per 100 000 pop.)', 'International migrant stock (000/% of total pop.)', 'Life expectancy at birth (females/males, years)', 'Population age distributiona,h (0-14/60+ years old, %)', 'Population growth rate (average annual %)', 'Refugees and others of concern to UNHCR (000)', 'Seats held by women in national parliaments (%)', 'Under five mortality rate (per 1000 live births)', 'Urban population (% of total population)', 'Urban population growth rate (average annual %)']
#        Country    Year Education: Government expenditure (% of GDP)  \
# 0  Afghanistan  2015.0                                          3.3
# 1  Afghanistan  2020.0                                          2.9
# 2  Afghanistan  2024.0                                          ...
# 3      Albania  2015.0                                          3.4
# 4      Albania  2020.0                                          3.3
#
#   Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                       85.9 / 125.4
# 1                                      88.3 / 130.6c
# 2                                          ... / ...
# 3                                      111.5 / 115.0
# 4                                       98.0 / 103.2
#
#   Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)  \
# 0                                        27.9 / 54.3
# 1                                       29.3 / 54.1q
# 2                                          ... / ...
# 3                                       91.5 / 105.3
# 4                                        89.4 / 97.2
#
#   Fertility rate, total (live births per woman)  \
# 0                                           5.7
# 1                                           5.1
# 2                                          4.8a
# 3                                           1.6
# 4                                           1.4
#
#   Health: Current expenditure (% of GDP) Health: Physicians (per 1 000 pop.)  \
# 0                                   10.1                                 0.3
# 1                                  15.5o                                 0.3
# 2                                21.8o,p                                 ...
# 3                                    6.5                                1.3o
# 4                                    7.5                                 1.9
#
#   Intentional homicide rate (per 100 000 pop.)  \
# 0                                           10
# 1                                          6.6
# 2                                           4p
# 3                                          2.2
# 4                                          2.1
#
#   International migrant stock (000/% of total pop.)  \
# 0                                      339.4 / 1.0m
# 1                                      144.1 / 0.4m
# 2                                         ... / ...
# 3                                        52.0 / 1.8
# 4                                        48.8 / 1.7
#
#   Life expectancy at birth (females/males, years)  \
# 0                                     64.2 / 60.4
# 1                                     64.7 / 58.5
# 2                                    67.8 / 64.7a
# 3                                     80.5 / 76.3
# 4                                     80.3 / 75.4
#
#   Population age distribution (0-14/60+ years old, %)  \
# 0                                         46.3 / 3.7
# 1                                         44.2 / 3.8
# 2                                        42.9 / 3.9a
# 3                                        19.0 / 17.7
# 4                                        17.5 / 21.1
#
#   Population growth rate (average annual %)  \
# 0                                       2.3
# 1                                       3.3
# 2                                      2.8a
# 3                                      -0.2
# 4                                      -0.4
#
#   Refugees and others of concern to UNHCR (000)  \
# 0                                       1 421.4
# 1                                       2 802.9
# 2                                      3 346.2j
# 3                                           8.1
# 4                                           3.6
#
#   Seats held by women in national parliaments (%)  \
# 0                                            27.7
# 1                                             27r
# 2                                         27r,s,b
# 3                                            20.7
# 4                                           29.5p
#
#   Under five mortality rate (per 1000 live births)  \
# 0                                             76.5
# 1                                             62.9
# 2                                            54.5a
# 3                                             10.1
# 4                                              9.4
#
#   Urban population (% of total population)  \
# 0                                     24.8
# 1                                    25.8c
# 2                                      ...
# 3                                     57.4
# 4                                    61.2c
#
#   Urban population growth rate (average annual %)
# 0                                              4k
# 1                                             ...
# 2                                             ...
# 3                                            1.8l
# 4                                             ...

# %%
numerical_cols=[
    "Education: Government expenditure (% of GDP)",
    "Fertility rate, total (live births per woman)",
    "Health: Current expenditure (% of GDP)",
    "Health: Physicians (per 1 000 pop.)",
    "Intentional homicide rate (per 100 000 pop.)",
    "Population growth rate (average annual %)",
    "Refugees and others of concern to UNHCR (000)",
    "Seats held by women in national parliaments (%)",
    "Under five mortality rate (per 1000 live births)",
    "Urban population (% of total population)",
    "Urban population growth rate (average annual %)"
]
df_social_indicators_flat = clean_numerical_cols(df_social_indicators_flat, numerical_cols)
df_social_indicators_flat.head()
# Out:
#        Country    Year  Education: Government expenditure (% of GDP)  \
# 0  Afghanistan  2015.0                                           3.3
# 1  Afghanistan  2020.0                                           2.9
# 2  Afghanistan  2024.0                                           NaN
# 3      Albania  2015.0                                           3.4
# 4      Albania  2020.0                                           3.3
#
#   Education: Primary gross enrol. ratio (f/m per 100 pop.)  \
# 0                                       85.9 / 125.4
# 1                                      88.3 / 130.6c
# 2                                          ... / ...
# 3                                      111.5 / 115.0
# 4                                       98.0 / 103.2
#
#   Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)  \
# 0                                        27.9 / 54.3
# 1                                       29.3 / 54.1q
# 2                                          ... / ...
# 3                                       91.5 / 105.3
# 4                                        89.4 / 97.2
#
#    Fertility rate, total (live births per woman)  \
# 0                                            5.7
# 1                                            5.1
# 2                                            4.8
# 3                                            1.6
# 4                                            1.4
#
#    Health: Current expenditure (% of GDP)  \
# 0                                    10.1
# 1                                    15.5
# 2                                    21.8
# 3                                     6.5
# 4                                     7.5
#
#    Health: Physicians (per 1 000 pop.)  \
# 0                                  0.3
# 1                                  0.3
# 2                                  NaN
# 3                                  1.3
# 4                                  1.9
#
#    Intentional homicide rate (per 100 000 pop.)  \
# 0                                          10.0
# 1                                           6.6
# 2                                           4.0
# 3                                           2.2
# 4                                           2.1
#
#   International migrant stock (000/% of total pop.)  \
# 0                                      339.4 / 1.0m
# 1                                      144.1 / 0.4m
# 2                                         ... / ...
# 3                                        52.0 / 1.8
# 4                                        48.8 / 1.7
#
#   Life expectancy at birth (females/males, years)  \
# 0                                     64.2 / 60.4
# 1                                     64.7 / 58.5
# 2                                    67.8 / 64.7a
# 3                                     80.5 / 76.3
# 4                                     80.3 / 75.4
#
#   Population age distribution (0-14/60+ years old, %)  \
# 0                                         46.3 / 3.7
# 1                                         44.2 / 3.8
# 2                                        42.9 / 3.9a
# 3                                        19.0 / 17.7
# 4                                        17.5 / 21.1
#
#    Population growth rate (average annual %)  \
# 0                                        2.3
# 1                                        3.3
# 2                                        2.8
# 3                                        0.2
# 4                                        0.4
#
#    Refugees and others of concern to UNHCR (000)  \
# 0                                         1421.4
# 1                                         2802.9
# 2                                         3346.2
# 3                                            8.1
# 4                                            3.6
#
#    Seats held by women in national parliaments (%)  \
# 0                                             27.7
# 1                                             27.0
# 2                                             27.0
# 3                                             20.7
# 4                                             29.5
#
#    Under five mortality rate (per 1000 live births)  \
# 0                                              76.5
# 1                                              62.9
# 2                                              54.5
# 3                                              10.1
# 4                                               9.4
#
#    Urban population (% of total population)  \
# 0                                      24.8
# 1                                      25.8
# 2                                       NaN
# 3                                      57.4
# 4                                      61.2
#
#    Urban population growth rate (average annual %)
# 0                                              4.0
# 1                                              NaN
# 2                                              NaN
# 3                                              1.8
# 4                                              NaN

# %%
# Define columns to split and their new column names
columns_to_split = [
    {
        "column": "Education: Primary gross enrol. ratio (f/m per 100 pop.)",
        "col1": "Education: Primary gross enrol. ratio - Female (per 100 pop.)",
        "col2": "Education: Primary gross enrol. ratio - Male (per 100 pop.)"
    },
    {
        "column": "Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)",
        "col1": "Education: Upper Sec. gross enrol. ratio - Female (per 100 pop.)",
        "col2": "Education: Upper Sec. gross enrol. ratio - Male (per 100 pop.)"
    },
    {
        "column": "Education: Lowr. sec. gross enrol. ratio (f/m per 100 pop.)",
        "col1": "Education: Lower Sec. gross enrol. ratio - Female (per 100 pop.)",
        "col2": "Education: Lower Sec. gross enrol. ratio - Male (per 100 pop.)"
    },
    {
        "column": "International migrant stock (000/% of total pop.)",
        "col1": "International migrant stock (000)",
        "col2": "International migrant stock (% of total pop.)"
    },
    {
        "column": "Life expectancy at birth (females/males, years)",
        "col1": "Life expectancy at birth - Female (years)",
        "col2": "Life expectancy at birth - Male (years)"
    },
    {
        "column": "Population age distribution (0-14/60+ years old, %)",
        "col1": "Population age distribution - 0-14 years (%)",
        "col2": "Population age distribution - 60+ years (%)"
    }
]

# Apply the split function to all columns
for split_info in columns_to_split:
    if split_info["column"] in df_social_indicators_flat.columns:
        print(f"\nProcessing: {split_info['column']}")
        df_social_indicators_flat = split_ratio_column(
            df=df_social_indicators_flat,
            column_to_split=split_info["column"],
            new_col1_name=split_info["col1"],
            new_col2_name=split_info["col2"]
        )
        # Drop the original column after splitting
        df_social_indicators_flat = df_social_indicators_flat.drop(columns=[split_info["column"]], axis=1)
    else:
        print(f"Warning: Column '{split_info['column']}' not found in dataframe")

print(f"\nFinal shape after splitting: {df_social_indicators_flat.shape}")
df_social_indicators_flat.head()
# Out:
# Processing: Education: Primary gross enrol. ratio (f/m per 100 pop.)
# Successfully split 'Education: Primary gross enrol. ratio (f/m per 100 pop.)' into:
#   - Education: Primary gross enrol. ratio - Female (per 100 pop.)
#   - Education: Primary gross enrol. ratio - Male (per 100 pop.)
#   - Education: Primary gross enrol. ratio - Female/Education: Primary gross enrol. ratio - Male Ratio
#
# Processing: Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)
# Successfully split 'Education: Upr. Sec. gross enrol. ratio (f/m per 100 pop.)' into:
#   - Education: Upper Sec. gross enrol. ratio - Female (per 100 pop.)
#   - Education: Upper Sec. gross enrol. ratio - Male (per 100 pop.)
#   - Education: Upper Sec. gross enrol. ratio - Female/Education: Upper Sec. gross enrol. ratio - Male Ratio
# Warning: Column 'Education: Lowr. sec. gross enrol. ratio (f/m per 100 pop.)' not found in dataframe
#
# Processing: International migrant stock (000/% of total pop.)
# Successfully split 'International migrant stock (000/% of total pop.)' into:
#   - International migrant stock (000)
#   - International migrant stock (% of total pop.)
#   - International migrant stock/International migrant stock Ratio
#
# Processing: Life expectancy at birth (females/males, years)
# Successfully split 'Life expectancy at birth (females/males, years)' into:
#   - Life expectancy at birth - Female (years)
#   - Life expectancy at birth - Male (years)
#   - Life expectancy at birth - Female/Life expectancy at birth - Male Ratio
#
# Processing: Population age distribution (0-14/60+ years old, %)
# Successfully split 'Population age distribution (0-14/60+ years old, %)' into:
#   - Population age distribution - 0-14 years (%)
#   - Population age distribution - 60+ years (%)
#   - Population age distribution - 0-14 years/Population age distribution - 60+ years Ratio
#
# Final shape after splitting: (696, 28)
#        Country    Year  Education: Government expenditure (% of GDP)  \
# 0  Afghanistan  2015.0                                           3.3
# 1  Afghanistan  2020.0                                           2.9
# 2  Afghanistan  2024.0                                           NaN
# 3      Albania  2015.0                                           3.4
# 4      Albania  2020.0                                           3.3
#
#    Fertility rate, total (live births per woman)  \
# 0                                            5.7
# 1                                            5.1
# 2                                            4.8
# 3                                            1.6
# 4                                            1.4
#
#    Health: Current expenditure (% of GDP)  \
# 0                                    10.1
# 1                                    15.5
# 2                                    21.8
# 3                                     6.5
# 4                                     7.5
#
#    Health: Physicians (per 1 000 pop.)  \
# 0                                  0.3
# 1                                  0.3
# 2                                  NaN
# 3                                  1.3
# 4                                  1.9
#
#    Intentional homicide rate (per 100 000 pop.)  \
# 0                                          10.0
# 1                                           6.6
# 2                                           4.0
# 3                                           2.2
# 4                                           2.1
#
#    Population growth rate (average annual %)  \
# 0                                        2.3
# 1                                        3.3
# 2                                        2.8
# 3                                        0.2
# 4                                        0.4
#
#    Refugees and others of concern to UNHCR (000)  \
# 0                                         1421.4
# 1                                         2802.9
# 2                                         3346.2
# 3                                            8.1
# 4                                            3.6
#
#    Seats held by women in national parliaments (%)  \
# 0                                             27.7
# 1                                             27.0
# 2                                             27.0
# 3                                             20.7
# 4                                             29.5
#
#    Under five mortality rate (per 1000 live births)  \
# 0                                              76.5
# 1                                              62.9
# 2                                              54.5
# 3                                              10.1
# 4                                               9.4
#
#    Urban population (% of total population)  \
# 0                                      24.8
# 1                                      25.8
# 2                                       NaN
# 3                                      57.4
# 4                                      61.2
#
#    Urban population growth rate (average annual %)  \
# 0                                              4.0
# 1                                              NaN
# 2                                              NaN
# 3                                              1.8
# 4                                              NaN
#
#    Education: Primary gross enrol. ratio - Female (per 100 pop.)  \
# 0                                               85.9
# 1                                               88.3
# 2                                                NaN
# 3                                              111.5
# 4                                               98.0
#
#    Education: Primary gross enrol. ratio - Male (per 100 pop.)  \
# 0                                              125.4
# 1                                              130.6
# 2                                                NaN
# 3                                              115.0
# 4                                              103.2
#
#    Education: Primary gross enrol. ratio - Female/Education: Primary gross enrol. ratio - Male Ratio  \
# 0                                          68.500797
# 1                                          67.611026
# 2                                                NaN
# 3                                          96.956522
# 4                                          94.961240
#
#    Education: Upper Sec. gross enrol. ratio - Female (per 100 pop.)  \
# 0                                               27.9
# 1                                               29.3
# 2                                                NaN
# 3                                               91.5
# 4                                               89.4
#
#    Education: Upper Sec. gross enrol. ratio - Male (per 100 pop.)  \
# 0                                               54.3
# 1                                               54.1
# 2                                                NaN
# 3                                              105.3
# 4                                               97.2
#
#    Education: Upper Sec. gross enrol. ratio - Female/Education: Upper Sec. gross enrol. ratio - Male Ratio  \
# 0                                          51.381215
# 1                                          54.158965
# 2                                                NaN
# 3                                          86.894587
# 4                                          91.975309
#
#    International migrant stock (000)  \
# 0                              339.4
# 1                              144.1
# 2                                NaN
# 3                               52.0
# 4                               48.8
#
#    International migrant stock (% of total pop.)  \
# 0                                            1.0
# 1                                            0.4
# 2                                            NaN
# 3                                            1.8
# 4                                            1.7
#
#    International migrant stock/International migrant stock Ratio  \
# 0                                       33940.000000
# 1                                       36025.000000
# 2                                                NaN
# 3                                        2888.888889
# 4                                        2870.588235
#
#    Life expectancy at birth - Female (years)  \
# 0                                       64.2
# 1                                       64.7
# 2                                       67.8
# 3                                       80.5
# 4                                       80.3
#
#    Life expectancy at birth - Male (years)  \
# 0                                     60.4
# 1                                     58.5
# 2                                     64.7
# 3                                     76.3
# 4                                     75.4
#
#    Life expectancy at birth - Female/Life expectancy at birth - Male Ratio  \
# 0                                         106.291391
# 1                                         110.598291
# 2                                         104.791345
# 3                                         105.504587
# 4                                         106.498674
#
#    Population age distribution - 0-14 years (%)  \
# 0                                          46.3
# 1                                          44.2
# 2                                          42.9
# 3                                          19.0
# 4                                          17.5
#
#    Population age distribution - 60+ years (%)  \
# 0                                          3.7
# 1                                          3.8
# 2                                          3.9
# 3                                         17.7
# 4                                         21.1
#
#    Population age distribution - 0-14 years/Population age distribution - 60+ years Ratio
# 0                                        1251.351351
# 1                                        1163.157895
# 2                                        1100.000000
# 3                                         107.344633
# 4                                          82.938389

# %% [markdown]
# ## environment and infrastructure indicators

# %%
df_env_infra_indicators.head()
# Out:
#          Country                                   Category  \
# 112  Afghanistan  Environment and infrastructure indicators
# 113  Afghanistan  Environment and infrastructure indicators
# 114  Afghanistan  Environment and infrastructure indicators
# 115  Afghanistan  Environment and infrastructure indicators
# 116  Afghanistan  Environment and infrastructure indicators
#
#                                              Indicator    Year    Value
# 112  Individuals using the Interneti (per 100 inhab...  2015.0      8.3
# 113  Individuals using the Interneti (per 100 inhab...  2020.0  17.6t,c
# 114  Individuals using the Interneti (per 100 inhab...  2024.0      ...
# 115                        Threatened species (number)  2015.0       38
# 116                        Threatened species (number)  2020.0       40

# %%
df_env_infra_indicators = df_env_infra_indicators.drop(columns=["Category"],axis=1)
df_env_infra_indicators.head()
# Out:
#          Country                                          Indicator    Year  \
# 112  Afghanistan  Individuals using the Interneti (per 100 inhab...  2015.0
# 113  Afghanistan  Individuals using the Interneti (per 100 inhab...  2020.0
# 114  Afghanistan  Individuals using the Interneti (per 100 inhab...  2024.0
# 115  Afghanistan                        Threatened species (number)  2015.0
# 116  Afghanistan                        Threatened species (number)  2020.0
#
#        Value
# 112      8.3
# 113  17.6t,c
# 114      ...
# 115       38
# 116       40

# %%
df_env_infra_indicators = pivot_df(df_env_infra_indicators, idx_cols=["Country","Year"])
df_env_infra_indicators.head()
# Out:
#        Country    Year CO2 emission estimates (million tons/tons per capita)  \
# 0  Afghanistan  2015.0                                          9.5 / 0.3
# 1  Afghanistan  2020.0                                         11.3 / 0.3
# 2  Afghanistan  2024.0                                      10.0 / 0.2i,p
# 3      Albania  2015.0                                          3.8 / 1.3
# 4      Albania  2020.0                                          3.5 / 1.2
#
#   CO2 emission estimatese (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesf (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesg (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesi (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesj (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesk (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesl (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesn (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimateso (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesp (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesv (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emission estimatesw (million tons/tons per capita)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Energy production, primary (Petajoules)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                      87
# 4                                      63
#
#   Energy production, primarya (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primarye (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryf (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryg (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryh (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryi (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryj (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryl (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryn (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryo (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryp (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryq (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryr (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryr,x (Petajoules)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Energy production, primarys (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryu (Petajoules)  \
# 0                                       61
# 1                                      78i
# 2                                    91i,p
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryu,v (Petajoules)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Energy production, primaryv (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryw (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy production, primaryx (Petajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy supply per capita (Gigajoules)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                    32
# 4                                    30
#
#   Energy supply per capitaa (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitae (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitaf (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitag (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitai (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitaj (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitak (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capital (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitan (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitao (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitap (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitaq (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitar (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitar,x (Gigajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy supply per capitas (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitau (Gigajoules)  \
# 0                                      5
# 1                                      5
# 2                                   4i,p
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitau,v (Gigajoules)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Energy supply per capitav (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitaw (Gigajoules)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Energy supply per capitax (Gigajoules) Forested area (% of land area)  \
# 0                                    NaN                            1.9
# 1                                    NaN                            1.9
# 2                                    NaN                           1.9p
# 3                                    NaN                          28.8i
# 4                                    NaN                          28.8i
#
#   Important sites for terrestrial biodiversity protected (%)  \
# 0                                                5.8
# 1                                               46.4
# 2                                              46.4j
# 3                                               47.7
# 4                                               48.6
#
#   Individuals using the Internet (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              56.9i
# 4                                              72.2q
#
#   Individuals using the Interneta,u (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetd (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internete (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetf (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetg (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Interneth (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Interneti (per 100 inhabitants)  \
# 0                                                8.3
# 1                                            17.6t,c
# 2                                                ...
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetj (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetk (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetl (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetm (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetn (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Interneto (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetp (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetp,q (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetq (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetq,r (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetr (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internets (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internett (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetu (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetv,w (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetw (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Individuals using the Internetx (per 100 inhabitants)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursed (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedp (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedq (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedr (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disburseds (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedt (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedu (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedv (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedw (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedx (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedy (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. disbursedz (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. received (% of GNI)  \
# 0                                              22.14
# 1                                              20.73
# 2                                                ...
# 3                                               2.91
# 4                                               2.08
#
#   Net Official Development Assist. receiveda (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. receivede (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Pop. using safely managed drinking water (urban/rural, %)  \
# 0                                        31.8 / 21.2
# 1                                        35.6 / 25.9
# 2                                       36.4 / 27.7b
# 3                                                NaN
# 4                                                NaN
#
#   Pop. using safely managed drinking watera (urban/rural, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Pop. using safely managed sanitation (urban/rural, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         34.0 / ...
# 4                                         45.2 / ...
#
#   Pop. using safely managed sanitationa (urban/rural, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Research & Development expenditure (% of GDP)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Research & Development expenditurea (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurek (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurel (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditureo (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurep (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurep,q (% of GDP)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Research & Development expenditureq (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurer (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditures (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditures,t (% of GDP)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Research & Development expendituret (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expendituret,v (% of GDP)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Research & Development expenditureu (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurev (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurev,w (% of GDP)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Research & Development expenditurex (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Research & Development expenditurey (% of GDP) Threatened species (number)  \
# 0                                            NaN                          38
# 1                                            NaN                          40
# 2                                            NaN                         57j
# 3                                            NaN                         112
# 4                                            NaN                         142
#
#   Threatened speciesa (number) Threatened speciesd (number)  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   Threatened speciesr (number) Threatened speciesu (number)  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   Tourist/visitor arrivals at national borders (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersa (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersk (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersk,r (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersn (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersn,o (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national borderso (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersp (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersp,q (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersq (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersq,r (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersr (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              3 784
# 4                                              2 604
#
#   Tourist/visitor arrivals at national bordersr,s (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersr,w (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national borderss (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national borderss,t (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national borderss,t,u (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national borderst (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national borderst,u (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersu (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersv (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersw (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersw,x (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersx (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersx,y (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersy (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersy,z (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tourist/visitor arrivals at national bordersz (000)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
print(list(df_env_infra_indicators.columns))
# Out:
# ['Country', 'Year', 'CO2 emission estimates (million tons/tons per capita)', 'CO2 emission estimatese (million tons/tons per capita)', 'CO2 emission estimatesf (million tons/tons per capita)', 'CO2 emission estimatesg (million tons/tons per capita)', 'CO2 emission estimatesi (million tons/tons per capita)', 'CO2 emission estimatesj (million tons/tons per capita)', 'CO2 emission estimatesk (million tons/tons per capita)', 'CO2 emission estimatesl (million tons/tons per capita)', 'CO2 emission estimatesn (million tons/tons per capita)', 'CO2 emission estimateso (million tons/tons per capita)', 'CO2 emission estimatesp (million tons/tons per capita)', 'CO2 emission estimatesv (million tons/tons per capita)', 'CO2 emission estimatesw (million tons/tons per capita)', 'Energy production, primary (Petajoules)', 'Energy production, primarya (Petajoules)', 'Energy production, primarye (Petajoules)', 'Energy production, primaryf (Petajoules)', 'Energy production, primaryg (Petajoules)', 'Energy production, primaryh (Petajoules)', 'Energy production, primaryi (Petajoules)', 'Energy production, primaryj (Petajoules)', 'Energy production, primaryl (Petajoules)', 'Energy production, primaryn (Petajoules)', 'Energy production, primaryo (Petajoules)', 'Energy production, primaryp (Petajoules)', 'Energy production, primaryq (Petajoules)', 'Energy production, primaryr (Petajoules)', 'Energy production, primaryr,x (Petajoules)', 'Energy production, primarys (Petajoules)', 'Energy production, primaryu (Petajoules)', 'Energy production, primaryu,v (Petajoules)', 'Energy production, primaryv (Petajoules)', 'Energy production, primaryw (Petajoules)', 'Energy production, primaryx (Petajoules)', 'Energy supply per capita (Gigajoules)', 'Energy supply per capitaa (Gigajoules)', 'Energy supply per capitae (Gigajoules)', 'Energy supply per capitaf (Gigajoules)', 'Energy supply per capitag (Gigajoules)', 'Energy supply per capitai (Gigajoules)', 'Energy supply per capitaj (Gigajoules)', 'Energy supply per capitak (Gigajoules)', 'Energy supply per capital (Gigajoules)', 'Energy supply per capitan (Gigajoules)', 'Energy supply per capitao (Gigajoules)', 'Energy supply per capitap (Gigajoules)', 'Energy supply per capitaq (Gigajoules)', 'Energy supply per capitar (Gigajoules)', 'Energy supply per capitar,x (Gigajoules)', 'Energy supply per capitas (Gigajoules)', 'Energy supply per capitau (Gigajoules)', 'Energy supply per capitau,v (Gigajoules)', 'Energy supply per capitav (Gigajoules)', 'Energy supply per capitaw (Gigajoules)', 'Energy supply per capitax (Gigajoules)', 'Forested area (% of land area)', 'Important sites for terrestrial biodiversity protected (%)', 'Individuals using the Internet (per 100 inhabitants)', 'Individuals using the Interneta,u (per 100 inhabitants)', 'Individuals using the Internetd (per 100 inhabitants)', 'Individuals using the Internete (per 100 inhabitants)', 'Individuals using the Internetf (per 100 inhabitants)', 'Individuals using the Internetg (per 100 inhabitants)', 'Individuals using the Interneth (per 100 inhabitants)', 'Individuals using the Interneti (per 100 inhabitants)', 'Individuals using the Internetj (per 100 inhabitants)', 'Individuals using the Internetk (per 100 inhabitants)', 'Individuals using the Internetl (per 100 inhabitants)', 'Individuals using the Internetm (per 100 inhabitants)', 'Individuals using the Internetn (per 100 inhabitants)', 'Individuals using the Interneto (per 100 inhabitants)', 'Individuals using the Internetp (per 100 inhabitants)', 'Individuals using the Internetp,q (per 100 inhabitants)', 'Individuals using the Internetq (per 100 inhabitants)', 'Individuals using the Internetq,r (per 100 inhabitants)', 'Individuals using the Internetr (per 100 inhabitants)', 'Individuals using the Internets (per 100 inhabitants)', 'Individuals using the Internett (per 100 inhabitants)', 'Individuals using the Internetu (per 100 inhabitants)', 'Individuals using the Internetv,w (per 100 inhabitants)', ' ...

# %%
root_column_names = [
    'CO2 emission estimates (million tons/tons per capita)',
    'Country',
    'Energy production, primary (Petajoules)',
    'Energy supply per capita (Gigajoules)',
    'Forested area (% of land area)',
    'Important sites for terrestrial biodiversity protected (%)',
    'Individuals using the Internet (per 100 inhabitants)',
    'Net Official Development Assist. disbursed (% of GNI)',
    'Net Official Development Assist. received (% of GNI)',
    'Pop. using safely managed drinking water (urban/rural, %)',
    'Pop. using safely managed sanitation (urban/rural, %)',
    'Research & Development expenditure (% of GDP)',
    'Threatened species (number)',
    'Tourist/visitor arrivals at national borders (000)',
    'Year'
]

df_env_infra_indicators = smart_combine_typo_columns(df_env_infra_indicators, root_column_names)
print(f"\nFinal shape: {df_env_infra_indicators.shape}")
print(f"Final columns: {list(df_env_infra_indicators.columns)}")
df_env_infra_indicators.head()
# Out:
# Merging into 'CO2 emission estimates (million tons/tons per capita)':
#   Found 12 similar columns
#   Merging: 'CO2 emission estimatese (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesf (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesg (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesi (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesj (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesk (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesl (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesn (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimateso (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesp (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesv (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#   Merging: 'CO2 emission estimatesw (million tons/tons per capita)' -> 'CO2 emission estimates (million tons/tons per capita)' (similarity: 0.991)
#
# Merging into 'Energy production, primary (Petajoules)':
#   Found 20 similar columns
#   Merging: 'Energy production, primarya (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primarye (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryf (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryg (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryh (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryi (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryj (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryl (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryn (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryo (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryp (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryq (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryr (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryr,x (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.963)
#   Merging: 'Energy production, primarys (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryu (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryu,v (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.963)
#   Merging: 'Energy production, primaryv (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryw (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#   Merging: 'Energy production, primaryx (Petajoules)' -> 'Energy production, primary (Petajoules)' (similarity: 0.987)
#
# Merging into 'Energy supply per capita (Gigajoules)':
#   Found 20 similar columns
#   Merging: 'Energy supply per capitaa (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitae (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitaf (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitag (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitai (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitaj (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitak (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capital (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitan (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitao (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitap (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitaq (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitar (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitar,x (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.961)
#   Merging: 'Energy supply per capitas (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitau (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitau,v (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.961)
#   Merging: 'Energy supply per capitav (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitaw (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#   Merging: 'Energy supply per capitax (Gigajoules)' -> 'Energy supply per capita (Gigajoules)' (similarity: 0.987)
#
# Merging into 'Individuals using the Internet (per 100 inhabitants)':
#   Found 24 similar columns
#   Merging: 'Individuals using the Interneta,u (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.972)
#   Merging: 'Individuals using the Internetd (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internete (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetf (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetg (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Interneth (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Interneti (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetj (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetk (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetl (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetm (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetn (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Interneto (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetp (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetp,q (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.972)
#   Merging: 'Individuals using the Internetq (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetq,r (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.972)
#   Merging: 'Individuals using the Internetr (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internets (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internett (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetu (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetv,w (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.972)
#   Merging: 'Individuals using the Internetw (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#   Merging: 'Individuals using the Internetx (per 100 inhabitants)' -> 'Individuals using the Internet (per 100 inhabitants)' (similarity: 0.990)
#
# Merging into 'Net Official Development Assist. disbursed (% of GNI)':
#   Found 13 similar columns
#   Merging: 'Net Official Development Assist. disbursedp (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedq (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedr (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disburseds (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedt (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedu (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedv (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedw (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedx (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedy (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. disbursedz (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.991)
#   Merging: 'Net Official Development Assist. receiveda (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.887)
#   Merging: 'Net Official Development Assist. receivede (% of GNI)' -> 'Net Official Development Assist. disbursed (% of GNI)' (similarity: 0.887)
#
# Merging into 'Pop. using safely managed drinking water (urban/rural, %)':
#   Found 2 similar columns
#   Merging: 'Pop. using safely managed drinking watera (urban/rural, %)' -> 'Pop. using safely managed drinking water (urban/rural, %)' (similarity: 0.991)
#   Merging: 'Pop. using safely managed sanitationa (urban/rural, %)' -> 'Pop. using safely managed drinking water (urban/rural, %)' (similarity: 0.829)
#
# Merging into 'Research & Development expenditure (% of GDP)':
#   Found 17 similar columns
#   Merging: 'Research & Development expenditurea (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurek (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurel (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditureo (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurep (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurep,q (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.968)
#   Merging: 'Research & Development expenditureq (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurer (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditures (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditures,t (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.968)
#   Merging: 'Research & Development expendituret (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expendituret,v (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.968)
#   Merging: 'Research & Development expenditureu (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurev (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurev,w (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.968)
#   Merging: 'Research & Development expenditurex (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#   Merging: 'Research & Development expenditurey (% of GDP)' -> 'Research & Development expenditure (% of GDP)' (similarity: 0.989)
#
# Merging into 'Threatened species (number)':
#   Found 4 similar columns
#   Merging: 'Threatened speciesa (number)' -> 'Threatened species (number)' (similarity: 0.982)
#   Merging: 'Threatened speciesd (number)' -> 'Threatened species (number)' (similarity: 0.982)
#   Merging: 'Threatened speciesr (number)' -> 'Threatened species (number)' (similarity: 0.982)
#   Merging: 'Threatened speciesu (number)' -> 'Threatened species (number)' (similarity: 0.982)
#
# Merging into 'Tourist/visitor arrivals at national borders (000)':
#   Found 27 similar columns
#   Merging: 'Tourist/visitor arrivals at national bordersa (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersk (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersk,r (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersn (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersn,o (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national borderso (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersp (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersp,q (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersq (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersq,r (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersr (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersr,s (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersr,w (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national borderss (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national borderss,t (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national borderss,t,u (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.952)
#   Merging: 'Tourist/visitor arrivals at national borderst (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national borderst,u (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersu (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersv (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersw (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersw,x (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersx (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersx,y (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersy (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#   Merging: 'Tourist/visitor arrivals at national bordersy,z (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.971)
#   Merging: 'Tourist/visitor arrivals at national bordersz (000)' -> 'Tourist/visitor arrivals at national borders (000)' (similarity: 0.990)
#
# Final shape: (696, 15)
# Final columns: ['Country', 'Year', 'CO2 emission estimates (million tons/tons per capita)', 'Energy production, primary (Petajoules)', 'Energy supply per capita (Gigajoules)', 'Forested area (% of land area)', 'Important sites for terrestrial biodiversity protected (%)', 'Individuals using the Internet (per 100 inhabitants)', 'Net Official Development Assist. disbursed (% of GNI)', 'Net Official Development Assist. received (% of GNI)', 'Pop. using safely managed drinking water (urban/rural, %)', 'Pop. using safely managed sanitation (urban/rural, %)', 'Research & Development expenditure (% of GDP)', 'Threatened species (number)', 'Tourist/visitor arrivals at national borders (000)']
#        Country    Year CO2 emission estimates (million tons/tons per capita)  \
# 0  Afghanistan  2015.0                                          9.5 / 0.3
# 1  Afghanistan  2020.0                                         11.3 / 0.3
# 2  Afghanistan  2024.0                                      10.0 / 0.2i,p
# 3      Albania  2015.0                                          3.8 / 1.3
# 4      Albania  2020.0                                          3.5 / 1.2
#
#   Energy production, primary (Petajoules)  \
# 0                                      61
# 1                                     78i
# 2                                   91i,p
# 3                                      87
# 4                                      63
#
#   Energy supply per capita (Gigajoules) Forested area (% of land area)  \
# 0                                     5                            1.9
# 1                                     5                            1.9
# 2                                  4i,p                           1.9p
# 3                                    32                          28.8i
# 4                                    30                          28.8i
#
#   Important sites for terrestrial biodiversity protected (%)  \
# 0                                                5.8
# 1                                               46.4
# 2                                              46.4j
# 3                                               47.7
# 4                                               48.6
#
#   Individuals using the Internet (per 100 inhabitants)  \
# 0                                                8.3
# 1                                            17.6t,c
# 2                                                ...
# 3                                              56.9i
# 4                                              72.2q
#
#   Net Official Development Assist. disbursed (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Net Official Development Assist. received (% of GNI)  \
# 0                                              22.14
# 1                                              20.73
# 2                                                ...
# 3                                               2.91
# 4                                               2.08
#
#   Pop. using safely managed drinking water (urban/rural, %)  \
# 0                                        31.8 / 21.2
# 1                                        35.6 / 25.9
# 2                                       36.4 / 27.7b
# 3                                                NaN
# 4                                                NaN
#
#   Pop. using safely managed sanitation (urban/rural, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         34.0 / ...
# 4                                         45.2 / ...
#
#   Research & Development expenditure (% of GDP) Threatened species (number)  \
# 0                                           NaN                          38
# 1                                           NaN                          40
# 2                                           NaN                         57j
# 3                                           NaN                         112
# 4                                           NaN                         142
#
#   Tourist/visitor arrivals at national borders (000)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              3 784
# 4                                              2 604

# %%
numerical_cols = [
    "Energy production, primary (Petajoules)",
    "Energy supply per capita (Gigajoules)",
    "Forested area (% of land area)",
    "Important sites for terrestrial biodiversity protected (%)",
    "Individuals using the Internet (per 100 inhabitants)",
    "Net Official Development Assist. disbursed (% of GNI)",
    "Net Official Development Assist. received (% of GNI)",
    "Research & Development expenditure (% of GDP)",
    "Threatened species (number)",
    "Tourist/visitor arrivals at national borders (000)"
]

df_env_infra_indicators = clean_numerical_cols(df_env_infra_indicators, numerical_cols)
df_env_infra_indicators.head()
# Out:
#        Country    Year CO2 emission estimates (million tons/tons per capita)  \
# 0  Afghanistan  2015.0                                          9.5 / 0.3
# 1  Afghanistan  2020.0                                         11.3 / 0.3
# 2  Afghanistan  2024.0                                      10.0 / 0.2i,p
# 3      Albania  2015.0                                          3.8 / 1.3
# 4      Albania  2020.0                                          3.5 / 1.2
#
#    Energy production, primary (Petajoules)  \
# 0                                     61.0
# 1                                     78.0
# 2                                     91.0
# 3                                     87.0
# 4                                     63.0
#
#    Energy supply per capita (Gigajoules)  Forested area (% of land area)  \
# 0                                    5.0                             1.9
# 1                                    5.0                             1.9
# 2                                    4.0                             1.9
# 3                                   32.0                            28.8
# 4                                   30.0                            28.8
#
#    Important sites for terrestrial biodiversity protected (%)  \
# 0                                                5.8
# 1                                               46.4
# 2                                               46.4
# 3                                               47.7
# 4                                               48.6
#
#    Individuals using the Internet (per 100 inhabitants)  \
# 0                                                8.3
# 1                                               17.6
# 2                                                NaN
# 3                                               56.9
# 4                                               72.2
#
#    Net Official Development Assist. disbursed (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Net Official Development Assist. received (% of GNI)  \
# 0                                              22.14
# 1                                              20.73
# 2                                                NaN
# 3                                               2.91
# 4                                               2.08
#
#   Pop. using safely managed drinking water (urban/rural, %)  \
# 0                                        31.8 / 21.2
# 1                                        35.6 / 25.9
# 2                                       36.4 / 27.7b
# 3                                                NaN
# 4                                                NaN
#
#   Pop. using safely managed sanitation (urban/rural, %)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         34.0 / ...
# 4                                         45.2 / ...
#
#    Research & Development expenditure (% of GDP)  Threatened species (number)  \
# 0                                            NaN                         38.0
# 1                                            NaN                         40.0
# 2                                            NaN                         57.0
# 3                                            NaN                        112.0
# 4                                            NaN                        142.0
#
#    Tourist/visitor arrivals at national borders (000)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             3784.0
# 4                                             2604.0

# %%
# Define columns to split and their new column names for environment & infrastructure indicators
columns_to_split = [
    {
        "column": "CO2 emission estimates (million tons/tons per capita)",
        "col1": "CO2 emission estimates - Total (million tons)",
        "col2": "CO2 emission estimates - Per capita (tons per capita)"
    },
    {
        "column": "Pop. using safely managed drinking water (urban/rural, %)",
        "col1": "Pop. using safely managed drinking water - Urban (%)",
        "col2": "Pop. using safely managed drinking water - Rural (%)"
    },
    {
        "column": "Pop. using safely managed sanitation (urban/rural, %)",
        "col1": "Pop. using safely managed sanitation - Urban (%)",
        "col2": "Pop. using safely managed sanitation - Rural (%)"
    }
]

# Apply the split function to all columns
for split_info in columns_to_split:
    if split_info["column"] in df_env_infra_indicators.columns:
        print(f"\nProcessing: {split_info['column']}")
        df_env_infra_indicators = split_ratio_column(
            df=df_env_infra_indicators,
            column_to_split=split_info["column"],
            new_col1_name=split_info["col1"],
            new_col2_name=split_info["col2"]
        )
        # Drop the original column after splitting
        df_env_infra_indicators = df_env_infra_indicators.drop(columns=[split_info["column"]], axis=1)
    else:
        print(f"Warning: Column '{split_info['column']}' not found in dataframe")

print(f"\nFinal shape after splitting: {df_env_infra_indicators.shape}")
df_env_infra_indicators.head()
# Out:
# Processing: CO2 emission estimates (million tons/tons per capita)
# Successfully split 'CO2 emission estimates (million tons/tons per capita)' into:
#   - CO2 emission estimates - Total (million tons)
#   - CO2 emission estimates - Per capita (tons per capita)
#   - CO2 emission estimates - Total/CO2 emission estimates - Per capita Ratio
#
# Processing: Pop. using safely managed drinking water (urban/rural, %)
# Successfully split 'Pop. using safely managed drinking water (urban/rural, %)' into:
#   - Pop. using safely managed drinking water - Urban (%)
#   - Pop. using safely managed drinking water - Rural (%)
#   - Pop. using safely managed drinking water - Urban/Pop. using safely managed drinking water - Rural Ratio
#
# Processing: Pop. using safely managed sanitation (urban/rural, %)
# Successfully split 'Pop. using safely managed sanitation (urban/rural, %)' into:
#   - Pop. using safely managed sanitation - Urban (%)
#   - Pop. using safely managed sanitation - Rural (%)
#   - Pop. using safely managed sanitation - Urban/Pop. using safely managed sanitation - Rural Ratio
#
# Final shape after splitting: (696, 21)
#        Country    Year  Energy production, primary (Petajoules)  \
# 0  Afghanistan  2015.0                                     61.0
# 1  Afghanistan  2020.0                                     78.0
# 2  Afghanistan  2024.0                                     91.0
# 3      Albania  2015.0                                     87.0
# 4      Albania  2020.0                                     63.0
#
#    Energy supply per capita (Gigajoules)  Forested area (% of land area)  \
# 0                                    5.0                             1.9
# 1                                    5.0                             1.9
# 2                                    4.0                             1.9
# 3                                   32.0                            28.8
# 4                                   30.0                            28.8
#
#    Important sites for terrestrial biodiversity protected (%)  \
# 0                                                5.8
# 1                                               46.4
# 2                                               46.4
# 3                                               47.7
# 4                                               48.6
#
#    Individuals using the Internet (per 100 inhabitants)  \
# 0                                                8.3
# 1                                               17.6
# 2                                                NaN
# 3                                               56.9
# 4                                               72.2
#
#    Net Official Development Assist. disbursed (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Net Official Development Assist. received (% of GNI)  \
# 0                                              22.14
# 1                                              20.73
# 2                                                NaN
# 3                                               2.91
# 4                                               2.08
#
#    Research & Development expenditure (% of GDP)  Threatened species (number)  \
# 0                                            NaN                         38.0
# 1                                            NaN                         40.0
# 2                                            NaN                         57.0
# 3                                            NaN                        112.0
# 4                                            NaN                        142.0
#
#    Tourist/visitor arrivals at national borders (000)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             3784.0
# 4                                             2604.0
#
#    CO2 emission estimates - Total (million tons)  \
# 0                                            9.5
# 1                                           11.3
# 2                                           10.0
# 3                                            3.8
# 4                                            3.5
#
#    CO2 emission estimates - Per capita (tons per capita)  \
# 0                                                0.3
# 1                                                0.3
# 2                                                0.2
# 3                                                1.3
# 4                                                1.2
#
#    CO2 emission estimates - Total/CO2 emission estimates - Per capita Ratio  \
# 0                                        3166.666667
# 1                                        3766.666667
# 2                                        5000.000000
# 3                                         292.307692
# 4                                         291.666667
#
#    Pop. using safely managed drinking water - Urban (%)  \
# 0                                               31.8
# 1                                               35.6
# 2                                               36.4
# 3                                                NaN
# 4                                                NaN
#
#    Pop. using safely managed drinking water - Rural (%)  \
# 0                                               21.2
# 1                                               25.9
# 2                                               27.7
# 3                                                NaN
# 4                                                NaN
#
#    Pop. using safely managed drinking water - Urban/Pop. using safely managed drinking water - Rural Ratio  \
# 0                                         150.000000
# 1                                         137.451737
# 2                                         131.407942
# 3                                                NaN
# 4                                                NaN
#
#    Pop. using safely managed sanitation - Urban (%)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                              34.0
# 4                                              45.2
#
#    Pop. using safely managed sanitation - Rural (%)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Pop. using safely managed sanitation - Urban/Pop. using safely managed sanitation - Rural Ratio
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ## Export Cleaned Data to CSV

# %%
import os

# Create clean_data directory if it doesn't exist
os.makedirs('clean_data', exist_ok=True)

# Export all cleaned dataframes to CSV
print("Exporting cleaned datasets...")

# General Information
df_general_info_flat.to_csv('clean_data/general_info_clean.csv', index=False)
print(f"✓ General Info: {df_general_info_flat.shape} -> clean_data/general_info_clean.csv")

# Economic Indicators  
df_economic_indicators_flat.to_csv('clean_data/economic_indicators_clean.csv', index=False)
print(f"✓ Economic Indicators: {df_economic_indicators_flat.shape} -> clean_data/economic_indicators_clean.csv")

# Social Indicators
df_social_indicators_flat.to_csv('clean_data/social_indicators_clean.csv', index=False)
print(f"✓ Social Indicators: {df_social_indicators_flat.shape} -> clean_data/social_indicators_clean.csv")

# Environment and Infrastructure Indicators
df_env_infra_indicators.to_csv('clean_data/environment_infrastructure_clean.csv', index=False)
print(f"✓ Environment & Infrastructure: {df_env_infra_indicators.shape} -> clean_data/environment_infrastructure_clean.csv")

print("\n🎉 All datasets exported successfully to clean_data/ directory!")
# Out:
# Exporting cleaned datasets...
# ✓ General Info: (232, 12) -> clean_data/general_info_clean.csv
# ✓ Economic Indicators: (687, 21) -> clean_data/economic_indicators_clean.csv
# ✓ Social Indicators: (696, 28) -> clean_data/social_indicators_clean.csv
# ✓ Environment & Infrastructure: (696, 21) -> clean_data/environment_infrastructure_clean.csv
#
# 🎉 All datasets exported successfully to clean_data/ directory!
